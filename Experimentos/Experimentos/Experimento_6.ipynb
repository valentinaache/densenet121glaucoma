# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    validation_split = 0.2
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.keras"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.5279
# Epoch 1: val_loss improved from inf to 1.62561, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 68s 5s/step - loss: 0.5336 - val_loss: 1.6256
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.4878
# Epoch 2: val_loss improved from 1.62561 to 0.79210, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 32s 456ms/step - loss: 0.4867 - val_loss: 0.7921
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4157
# Epoch 3: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.4170 - val_loss: 1.0852
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.3855
# Epoch 4: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - loss: 0.3875 - val_loss: 1.1136
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.4026
# Epoch 5: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - loss: 0.4013 - val_loss: 0.9180
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.3954
# Epoch 6: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - loss: 0.3918 - val_loss: 1.3052
# Epoch 7/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.3361
# Epoch 7: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step - loss: 0.3399 - val_loss: 1.0921
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.3225
# Epoch 8: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - loss: 0.3228 - val_loss: 1.1186
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.3055
# Epoch 9: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - loss: 0.3074 - val_loss: 1.1454
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.4048
# Epoch 10: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 236ms/step - loss: 0.3986 - val_loss: 1.1286
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.2756
# Epoch 11: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - loss: 0.2792 - val_loss: 1.2913
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.3209
# Epoch 12: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - loss: 0.3189 - val_loss: 1.1040
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.3262
# Epoch 13: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - loss: 0.3240 - val_loss: 1.4066
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.3253
# Epoch 14: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 442ms/step - loss: 0.3224 - val_loss: 1.3320
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.2358
# Epoch 15: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 234ms/step - loss: 0.2403 - val_loss: 1.2717
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2820
# Epoch 16: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 214ms/step - loss: 0.2829 - val_loss: 1.2977
# Epoch 17/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.2885
# Epoch 17: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 234ms/step - loss: 0.2865 - val_loss: 1.2508
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.2744
# Epoch 18: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - loss: 0.2742 - val_loss: 1.4002
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.2343
# Epoch 19: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 354ms/step - loss: 0.2387 - val_loss: 1.1917
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.2512
# Epoch 20: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 230ms/step - loss: 0.2531 - val_loss: 1.2960
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.3564
# Epoch 21: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - loss: 0.3495 - val_loss: 1.1778
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.2597
# Epoch 22: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 203ms/step - loss: 0.2590 - val_loss: 1.4787
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.2493
# Epoch 23: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.2491 - val_loss: 1.2728
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.2194
# Epoch 24: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 437ms/step - loss: 0.2221 - val_loss: 1.2455
# Epoch 25/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2723
# Epoch 25: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 202ms/step - loss: 0.2691 - val_loss: 1.5299
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.2337
# Epoch 26: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - loss: 0.2364 - val_loss: 1.5182
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.1953
# Epoch 27: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - loss: 0.2003 - val_loss: 1.1264
# Epoch 28/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.2528
# Epoch 28: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.2505 - val_loss: 1.3559
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.2005
# Epoch 29: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 468ms/step - loss: 0.2049 - val_loss: 1.5250
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.2168
# Epoch 30: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 236ms/step - loss: 0.2201 - val_loss: 1.0192
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.2377
# Epoch 31: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - loss: 0.2412 - val_loss: 1.5441
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.2123
# Epoch 32: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - loss: 0.2124 - val_loss: 1.2719
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2562
# Epoch 33: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 285ms/step - loss: 0.2539 - val_loss: 1.5362
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.2476
# Epoch 34: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step - loss: 0.2494 - val_loss: 1.2898
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2069
# Epoch 35: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - loss: 0.2098 - val_loss: 1.2924
# Epoch 36/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.2430
# Epoch 36: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 465ms/step - loss: 0.2404 - val_loss: 1.5573
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.3040
# Epoch 37: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 0.2993 - val_loss: 1.1466
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.2302
# Epoch 38: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 439ms/step - loss: 0.2323 - val_loss: 1.5670
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.1999
# Epoch 39: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - loss: 0.2011 - val_loss: 1.3309
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2350
# Epoch 40: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - loss: 0.2340 - val_loss: 1.5205
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.1850
# Epoch 41: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - loss: 0.1859 - val_loss: 1.3256
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.1899
# Epoch 42: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - loss: 0.1907 - val_loss: 1.5159
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.2423
# Epoch 43: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.2401 - val_loss: 1.3162
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.1732
# Epoch 44: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1760 - val_loss: 1.2706
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.1949
# Epoch 45: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 435ms/step - loss: 0.1963 - val_loss: 1.3463
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.1906
# Epoch 46: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step - loss: 0.1913 - val_loss: 1.3889
# Epoch 47/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.2131
# Epoch 47: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.2103 - val_loss: 1.3665
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.2223
# Epoch 48: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - loss: 0.2217 - val_loss: 1.3961
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.1711
# Epoch 49: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - loss: 0.1744 - val_loss: 1.4821
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.1979
# Epoch 50: val_loss did not improve from 0.79210
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step - loss: 0.1981 - val_loss: 1.5641

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.keras")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.0000001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.keras"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.5096
# Epoch 1: val_loss improved from inf to 0.78884, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 273s 14s/step - loss: 0.5117 - val_loss: 0.7888
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - loss: 0.5638
# Epoch 2: val_loss improved from 0.78884 to 0.76943, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 54s 632ms/step - loss: 0.5615 - val_loss: 0.7694
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - loss: 0.5747
# Epoch 3: val_loss did not improve from 0.76943
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 438ms/step - loss: 0.5710 - val_loss: 0.7729
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - loss: 0.4361
# Epoch 4: val_loss did not improve from 0.76943
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 452ms/step - loss: 0.4450 - val_loss: 0.7961
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.5461
# Epoch 5: val_loss did not improve from 0.76943
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 375ms/step - loss: 0.5448 - val_loss: 0.7994
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - loss: 0.5566
# Epoch 6: val_loss improved from 0.76943 to 0.75045, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 677ms/step - loss: 0.5530 - val_loss: 0.7505
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 0.5193
# Epoch 7: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - loss: 0.5208 - val_loss: 0.7923
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - loss: 0.4827
# Epoch 8: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 438ms/step - loss: 0.4834 - val_loss: 0.7664
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.5185
# Epoch 9: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 604ms/step - loss: 0.5169 - val_loss: 0.8105
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 0.4495
# Epoch 10: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 432ms/step - loss: 0.4560 - val_loss: 0.7976
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 0.4892
# Epoch 11: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 473ms/step - loss: 0.4908 - val_loss: 0.8105
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - loss: 0.4422
# Epoch 12: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 395ms/step - loss: 0.4472 - val_loss: 0.8077
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.5117
# Epoch 13: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 396ms/step - loss: 0.5115 - val_loss: 0.8243
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.4760
# Epoch 14: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 435ms/step - loss: 0.4796 - val_loss: 0.8285
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.6347
# Epoch 15: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - loss: 0.6232 - val_loss: 0.7848
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - loss: 0.6045
# Epoch 16: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 381ms/step - loss: 0.5980 - val_loss: 0.7889
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - loss: 0.5442
# Epoch 17: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 378ms/step - loss: 0.5422 - val_loss: 0.7889
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - loss: 0.4616
# Epoch 18: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 439ms/step - loss: 0.4677 - val_loss: 0.8156
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - loss: 0.4981
# Epoch 19: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 435ms/step - loss: 0.4989 - val_loss: 0.8462
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - loss: 0.6067
# Epoch 20: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 437ms/step - loss: 0.5959 - val_loss: 0.8249
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.4757
# Epoch 21: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 442ms/step - loss: 0.4779 - val_loss: 0.7882
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 0.5039
# Epoch 22: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 394ms/step - loss: 0.5021 - val_loss: 0.8154
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - loss: 0.5276
# Epoch 23: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 426ms/step - loss: 0.5270 - val_loss: 0.8426
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - loss: 0.4701
# Epoch 24: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 635ms/step - loss: 0.4727 - val_loss: 0.8446
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 0.5290
# Epoch 25: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - loss: 0.5265 - val_loss: 0.7978
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - loss: 0.5021
# Epoch 26: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 421ms/step - loss: 0.4999 - val_loss: 0.8490
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.5193
# Epoch 27: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 603ms/step - loss: 0.5197 - val_loss: 0.8499
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - loss: 0.5356
# Epoch 28: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - loss: 0.5308 - val_loss: 0.8246
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - loss: 0.4451
# Epoch 29: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 591ms/step - loss: 0.4530 - val_loss: 0.8499
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.5118
# Epoch 30: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 394ms/step - loss: 0.5094 - val_loss: 0.8257
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.4476
# Epoch 31: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 396ms/step - loss: 0.4533 - val_loss: 0.8621
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.4274
# Epoch 32: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 463ms/step - loss: 0.4330 - val_loss: 0.8186
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - loss: 0.4364
# Epoch 33: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - loss: 0.4424 - val_loss: 0.8229
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.5641
# Epoch 34: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 606ms/step - loss: 0.5565 - val_loss: 0.8297
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.4459
# Epoch 35: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 398ms/step - loss: 0.4502 - val_loss: 0.8624
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - loss: 0.5760
# Epoch 36: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 430ms/step - loss: 0.5682 - val_loss: 0.8632
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - loss: 0.4245
# Epoch 37: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - loss: 0.4299 - val_loss: 0.8672
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.5166
# Epoch 38: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 403ms/step - loss: 0.5151 - val_loss: 0.8311
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - loss: 0.4983
# Epoch 39: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 429ms/step - loss: 0.4963 - val_loss: 0.8509
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.4908
# Epoch 40: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 604ms/step - loss: 0.4912 - val_loss: 0.9235
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - loss: 0.4522
# Epoch 41: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 429ms/step - loss: 0.4540 - val_loss: 0.8856
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - loss: 0.4592
# Epoch 42: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 374ms/step - loss: 0.4623 - val_loss: 0.8450
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.4724
# Epoch 43: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 602ms/step - loss: 0.4741 - val_loss: 0.9204
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - loss: 0.4874
# Epoch 44: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - loss: 0.4878 - val_loss: 0.8740
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 0.5383
# Epoch 45: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 471ms/step - loss: 0.5354 - val_loss: 0.9137
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.5100
# Epoch 46: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 441ms/step - loss: 0.5072 - val_loss: 0.8971
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - loss: 0.6155
# Epoch 47: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 370ms/step - loss: 0.6043 - val_loss: 0.8833
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.4475
# Epoch 48: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 463ms/step - loss: 0.4520 - val_loss: 0.9229
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - loss: 0.5051
# Epoch 49: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - loss: 0.5018 - val_loss: 0.9445
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - loss: 0.4787
# Epoch 50: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 430ms/step - loss: 0.4789 - val_loss: 0.9190
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.5144
# Epoch 51: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 395ms/step - loss: 0.5134 - val_loss: 0.8638
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.4993
# Epoch 52: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 507ms/step - loss: 0.4992 - val_loss: 0.9027
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - loss: 0.4972
# Epoch 53: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 392ms/step - loss: 0.4969 - val_loss: 0.9579
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - loss: 0.5201
# Epoch 54: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 429ms/step - loss: 0.5189 - val_loss: 0.9442
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.4440
# Epoch 55: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - loss: 0.4473 - val_loss: 0.9362
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.4966
# Epoch 56: val_loss did not improve from 0.75045
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - loss: 0.4958 - val_loss: 0.9223

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator, verbose=1)
y_test = test_generator.classes


thresholds = np.arange(0.1, 1.0, 0.1)
best_threshold = 0.5
best_f1 = 0

for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    f1 = f1_score(y_test, predicted_classes_test)
    precision = precision_score(y_test, predicted_classes_test)
    recall = recall_score(y_test, predicted_classes_test)

    print(f'Threshold: {threshold:.2f}')
    print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}\n')


    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f'Mejor threshold: {best_threshold} con F1 Score: {best_f1}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step
# Threshold: 0.10
# Precision: 0.2024, Recall: 1.0000, F1 Score: 0.3366
#
# Threshold: 0.20
# Precision: 0.2000, Recall: 0.9412, F1 Score: 0.3299
#
# Threshold: 0.30
# Precision: 0.2308, Recall: 0.8824, F1 Score: 0.3659
#
# Threshold: 0.40
# Precision: 0.3250, Recall: 0.7647, F1 Score: 0.4561
#
# Threshold: 0.50
# Precision: 0.3846, Recall: 0.2941, F1 Score: 0.3333
#
# Threshold: 0.60
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.70
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.80
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.90
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Mejor threshold: 0.4 con F1 Score: 0.45614035087719296
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# Inicializar listas para almacenar las métricas
precisions = []
recalls = []
f1_scores = []

# Iterar sobre diferentes thresholds y calcular las métricas
for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    precisions.append(precision_score(y_test, predicted_classes_test))
    recalls.append(recall_score(y_test, predicted_classes_test))
    f1_scores.append(f1_score(y_test, predicted_classes_test))

# Graficar las métricas en función de los thresholds
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions, label='Precision')
plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, f1_scores, label='F1 Score')
plt.xlabel('Threshold')
plt.ylabel('Metric Value')
plt.title('Metrics vs. Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Evaluar con el mejor threshold encontrado
predicted_classes_test = (predictions_test >= best_threshold).astype(int)
print("Test set classification report with custom threshold:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))

precision = precision_score(y_test, predicted_classes_test)
recall = recall_score(y_test, predicted_classes_test)

print("Precision (Test Set, Class 1) with custom threshold:", precision)
print("Recall (Test Set, Class 1) with custom threshold:", recall)

auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score:", auc_score_test)
# Out:
# Test set classification report with custom threshold:
#               precision    recall  f1-score   support
#
#      Clase 0       0.91      0.60      0.72        67
#      Clase 1       0.33      0.76      0.46        17
#
#     accuracy                           0.63        84
#    macro avg       0.62      0.68      0.59        84
# weighted avg       0.79      0.63      0.67        84
#
# Precision (Test Set, Class 1) with custom threshold: 0.325
# Recall (Test Set, Class 1) with custom threshold: 0.7647058823529411
# Test set AUC Score: 0.6918349429323968

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, predictions_test)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# #RESULTADOS ANTERIORES

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.82      0.82      0.82        67
#      Clase 1       0.29      0.29      0.29        17
#
#     accuracy                           0.71        84
#    macro avg       0.56      0.56      0.56        84
# weighted avg       0.71      0.71      0.71        84
#
# Test set AUC Score after warmup: 0.6057945566286216
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.87      0.94      0.90       265
#      Clase 1       0.66      0.47      0.55        70
#
#     accuracy                           0.84       335
#    macro avg       0.77      0.70      0.73       335
# weighted avg       0.83      0.84      0.83       335
#
# Train set AUC Score after warmup: 0.7901347708894879

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.82      0.91      0.87        67
#      Clase 1       0.40      0.24      0.30        17
#
#     accuracy                           0.77        84
#    macro avg       0.61      0.57      0.58        84
# weighted avg       0.74      0.77      0.75        84
#
# Test set AUC Score after fine-tuning: 0.5381913959613697
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 560ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.81      0.90      0.85       265
#      Clase 1       0.36      0.21      0.27        70
#
#     accuracy                           0.76       335
#    macro avg       0.58      0.56      0.56       335
# weighted avg       0.72      0.76      0.73       335
#
# Train set AUC Score after fine-tuning: 0.6294878706199462

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')

# %%
from sklearn.metrics import precision_score, recall_score

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)
y_test = test_generator.classes

precision = precision_score(y_test, predicted_classes_test, average='binary', pos_label=1)
recall = recall_score(y_test, predicted_classes_test, average='binary', pos_label=1)

print("Precision (Test Set, Class 1):", precision)
print("Recall (Test Set, Class 1):", recall)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Precision (Test Set, Class 1): 0.4
# Recall (Test Set, Class 1): 0.23529411764705882
