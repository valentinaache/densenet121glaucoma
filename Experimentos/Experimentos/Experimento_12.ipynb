# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet  import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=15,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    validation_split = 0.25
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 252 validated image filenames belonging to 2 classes.
# Found 83 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.h5"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2742
# Epoch 1: val_loss improved from inf to 1.40696, saving model to best_model_warmup.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - 44s 6s/step - loss: 0.2742 - val_loss: 1.4070
# Epoch 2/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2489
# Epoch 2: val_loss did not improve from 1.40696
# 8/8 [==============================] - 5s 663ms/step - loss: 0.2489 - val_loss: 1.6585
# Epoch 3/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2364
# Epoch 3: val_loss improved from 1.40696 to 1.37488, saving model to best_model_warmup.h5
# 8/8 [==============================] - 7s 988ms/step - loss: 0.2364 - val_loss: 1.3749
# Epoch 4/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2149
# Epoch 4: val_loss improved from 1.37488 to 1.32216, saving model to best_model_warmup.h5
# 8/8 [==============================] - 6s 739ms/step - loss: 0.2149 - val_loss: 1.3222
# Epoch 5/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2048
# Epoch 5: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 756ms/step - loss: 0.2048 - val_loss: 1.5254
# Epoch 6/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2004
# Epoch 6: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 687ms/step - loss: 0.2004 - val_loss: 1.8622
# Epoch 7/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2056
# Epoch 7: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 850ms/step - loss: 0.2056 - val_loss: 1.4276
# Epoch 8/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1971
# Epoch 8: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 641ms/step - loss: 0.1971 - val_loss: 1.5517
# Epoch 9/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1805
# Epoch 9: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 824ms/step - loss: 0.1805 - val_loss: 1.9758
# Epoch 10/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1899
# Epoch 10: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 644ms/step - loss: 0.1899 - val_loss: 1.5617
# Epoch 11/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1988
# Epoch 11: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 901ms/step - loss: 0.1988 - val_loss: 1.4873
# Epoch 12/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1921
# Epoch 12: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 644ms/step - loss: 0.1921 - val_loss: 1.9347
# Epoch 13/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1597
# Epoch 13: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 855ms/step - loss: 0.1597 - val_loss: 1.5458
# Epoch 14/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1599
# Epoch 14: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 843ms/step - loss: 0.1599 - val_loss: 1.7873
# Epoch 15/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1744
# Epoch 15: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 638ms/step - loss: 0.1744 - val_loss: 1.7789
# Epoch 16/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1540
# Epoch 16: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 837ms/step - loss: 0.1540 - val_loss: 1.6457
# Epoch 17/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1550
# Epoch 17: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 633ms/step - loss: 0.1550 - val_loss: 1.8854
# Epoch 18/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1634
# Epoch 18: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 861ms/step - loss: 0.1634 - val_loss: 1.6628
# Epoch 19/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1538
# Epoch 19: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 637ms/step - loss: 0.1538 - val_loss: 1.6423
# Epoch 20/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1486
# Epoch 20: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 635ms/step - loss: 0.1486 - val_loss: 1.9694
# Epoch 21/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1633
# Epoch 21: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 817ms/step - loss: 0.1633 - val_loss: 1.5228
# Epoch 22/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1586
# Epoch 22: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 719ms/step - loss: 0.1586 - val_loss: 1.8793
# Epoch 23/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1426
# Epoch 23: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 637ms/step - loss: 0.1426 - val_loss: 1.9553
# Epoch 24/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1488
# Epoch 24: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 864ms/step - loss: 0.1488 - val_loss: 1.8673
# Epoch 25/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1305
# Epoch 25: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 632ms/step - loss: 0.1305 - val_loss: 1.8043
# Epoch 26/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1508
# Epoch 26: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 728ms/step - loss: 0.1508 - val_loss: 1.8805
# Epoch 27/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1505
# Epoch 27: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 702ms/step - loss: 0.1505 - val_loss: 1.7476
# Epoch 28/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1465
# Epoch 28: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 639ms/step - loss: 0.1465 - val_loss: 1.9025
# Epoch 29/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1180
# Epoch 29: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 836ms/step - loss: 0.1180 - val_loss: 1.7565
# Epoch 30/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1270
# Epoch 30: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 656ms/step - loss: 0.1270 - val_loss: 1.8721
# Epoch 31/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1237
# Epoch 31: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 799ms/step - loss: 0.1237 - val_loss: 1.8609
# Epoch 32/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1280
# Epoch 32: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 646ms/step - loss: 0.1280 - val_loss: 1.8749
# Epoch 33/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1290
# Epoch 33: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 824ms/step - loss: 0.1290 - val_loss: 2.0995
# Epoch 34/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1255
# Epoch 34: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 646ms/step - loss: 0.1255 - val_loss: 1.9635
# Epoch 35/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1144
# Epoch 35: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 829ms/step - loss: 0.1144 - val_loss: 1.8294
# Epoch 36/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1262
# Epoch 36: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 633ms/step - loss: 0.1262 - val_loss: 2.1003
# Epoch 37/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1189
# Epoch 37: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 852ms/step - loss: 0.1189 - val_loss: 1.9915
# Epoch 38/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1133
# Epoch 38: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 632ms/step - loss: 0.1133 - val_loss: 2.1963
# Epoch 39/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1322
# Epoch 39: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 820ms/step - loss: 0.1322 - val_loss: 1.8407
# Epoch 40/50
# 8/8 [==============================] - ETA: 0s - loss: 0.0975
# Epoch 40: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 641ms/step - loss: 0.0975 - val_loss: 2.1354
# Epoch 41/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1132
# Epoch 41: val_loss did not improve from 1.32216
# 8/8 [==============================] - 7s 854ms/step - loss: 0.1132 - val_loss: 1.9969
# Epoch 42/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1186
# Epoch 42: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 637ms/step - loss: 0.1186 - val_loss: 2.0745
# Epoch 43/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1264
# Epoch 43: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 754ms/step - loss: 0.1264 - val_loss: 1.8514
# Epoch 44/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1282
# Epoch 44: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 694ms/step - loss: 0.1282 - val_loss: 1.9074
# Epoch 45/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1189
# Epoch 45: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 850ms/step - loss: 0.1189 - val_loss: 2.4304
# Epoch 46/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1261
# Epoch 46: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 629ms/step - loss: 0.1261 - val_loss: 1.8452
# Epoch 47/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1190
# Epoch 47: val_loss did not improve from 1.32216
# 8/8 [==============================] - 6s 821ms/step - loss: 0.1190 - val_loss: 2.2201
# Epoch 48/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1010
# Epoch 48: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 655ms/step - loss: 0.1010 - val_loss: 2.1417
# Epoch 49/50
# 8/8 [==============================] - ETA: 0s - loss: 0.0972
# Epoch 49: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 639ms/step - loss: 0.0972 - val_loss: 2.3181
# Epoch 50/50
# 8/8 [==============================] - ETA: 0s - loss: 0.0994
# Epoch 50: val_loss did not improve from 1.32216
# 8/8 [==============================] - 5s 634ms/step - loss: 0.0994 - val_loss: 2.0410

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')
# Out:
# 3/3 [==============================] - 49s 24s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      0.99      0.88        67
#      Clase 1       0.00      0.00      0.00        17
#
#     accuracy                           0.79        84
#    macro avg       0.40      0.49      0.44        84
# weighted avg       0.63      0.79      0.70        84
#
# Test set AUC Score after warmup: 0.5899912203687445
# 11/11 [==============================] - 5s 499ms/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.82      0.99      0.90       265
#      Clase 1       0.82      0.20      0.32        70
#
#     accuracy                           0.82       335
#    macro avg       0.82      0.59      0.61       335
# weighted avg       0.82      0.82      0.78       335
#
# Train set AUC Score after warmup: 0.7138544474393531

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.h5")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.h5"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2855
# Epoch 1: val_loss improved from inf to 1.71053, saving model to best_model_finetune.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - 80s 2s/step - loss: 0.2855 - val_loss: 1.7105
# Epoch 2/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2497
# Epoch 2: val_loss did not improve from 1.71053
# 8/8 [==============================] - 8s 905ms/step - loss: 0.2497 - val_loss: 1.8624
# Epoch 3/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2448
# Epoch 3: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 742ms/step - loss: 0.2448 - val_loss: 2.0225
# Epoch 4/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2433
# Epoch 4: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 890ms/step - loss: 0.2433 - val_loss: 2.0252
# Epoch 5/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2564
# Epoch 5: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 715ms/step - loss: 0.2564 - val_loss: 2.1150
# Epoch 6/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2459
# Epoch 6: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 922ms/step - loss: 0.2459 - val_loss: 2.2215
# Epoch 7/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2180
# Epoch 7: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 737ms/step - loss: 0.2180 - val_loss: 2.2884
# Epoch 8/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2084
# Epoch 8: val_loss did not improve from 1.71053
# 8/8 [==============================] - 9s 1s/step - loss: 0.2084 - val_loss: 2.2787
# Epoch 9/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1753
# Epoch 9: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 723ms/step - loss: 0.1753 - val_loss: 2.3534
# Epoch 10/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1871
# Epoch 10: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 900ms/step - loss: 0.1871 - val_loss: 2.4580
# Epoch 11/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 11: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 719ms/step - loss: 0.1699 - val_loss: 2.4459
# Epoch 12/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1800
# Epoch 12: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 937ms/step - loss: 0.1800 - val_loss: 2.4277
# Epoch 13/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1696
# Epoch 13: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 718ms/step - loss: 0.1696 - val_loss: 2.4608
# Epoch 14/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1764
# Epoch 14: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 713ms/step - loss: 0.1764 - val_loss: 2.5159
# Epoch 15/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1456
# Epoch 15: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 931ms/step - loss: 0.1456 - val_loss: 2.5475
# Epoch 16/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1546
# Epoch 16: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 727ms/step - loss: 0.1546 - val_loss: 2.5391
# Epoch 17/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1637
# Epoch 17: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 812ms/step - loss: 0.1637 - val_loss: 2.6667
# Epoch 18/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1438
# Epoch 18: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 923ms/step - loss: 0.1438 - val_loss: 2.6123
# Epoch 19/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1481
# Epoch 19: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 705ms/step - loss: 0.1481 - val_loss: 2.6471
# Epoch 20/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1525
# Epoch 20: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 902ms/step - loss: 0.1525 - val_loss: 2.5706
# Epoch 21/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1333
# Epoch 21: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 717ms/step - loss: 0.1333 - val_loss: 2.7166
# Epoch 22/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1085
# Epoch 22: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 715ms/step - loss: 0.1085 - val_loss: 2.6835
# Epoch 23/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1372
# Epoch 23: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 750ms/step - loss: 0.1372 - val_loss: 2.7257
# Epoch 24/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1173
# Epoch 24: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 780ms/step - loss: 0.1173 - val_loss: 2.7414
# Epoch 25/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1009
# Epoch 25: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 839ms/step - loss: 0.1009 - val_loss: 2.7617
# Epoch 26/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1131
# Epoch 26: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 748ms/step - loss: 0.1131 - val_loss: 2.7299
# Epoch 27/200
# 8/8 [==============================] - ETA: 0s - loss: 0.1097
# Epoch 27: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 885ms/step - loss: 0.1097 - val_loss: 2.6449
# Epoch 28/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0990
# Epoch 28: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 718ms/step - loss: 0.0990 - val_loss: 2.6272
# Epoch 29/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0898
# Epoch 29: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 916ms/step - loss: 0.0898 - val_loss: 2.6570
# Epoch 30/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0905
# Epoch 30: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 836ms/step - loss: 0.0905 - val_loss: 2.5719
# Epoch 31/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0790
# Epoch 31: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 793ms/step - loss: 0.0790 - val_loss: 2.7099
# Epoch 32/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0887
# Epoch 32: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 752ms/step - loss: 0.0887 - val_loss: 2.6241
# Epoch 33/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0889
# Epoch 33: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 714ms/step - loss: 0.0889 - val_loss: 2.6461
# Epoch 34/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0900
# Epoch 34: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 716ms/step - loss: 0.0900 - val_loss: 2.6115
# Epoch 35/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0762
# Epoch 35: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 797ms/step - loss: 0.0762 - val_loss: 2.6199
# Epoch 36/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0596
# Epoch 36: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 716ms/step - loss: 0.0596 - val_loss: 2.6226
# Epoch 37/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0746
# Epoch 37: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 894ms/step - loss: 0.0746 - val_loss: 2.5978
# Epoch 38/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0669
# Epoch 38: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 838ms/step - loss: 0.0669 - val_loss: 2.6997
# Epoch 39/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0624
# Epoch 39: val_loss did not improve from 1.71053
# 8/8 [==============================] - 8s 987ms/step - loss: 0.0624 - val_loss: 2.6849
# Epoch 40/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0719
# Epoch 40: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 912ms/step - loss: 0.0719 - val_loss: 2.7193
# Epoch 41/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0545
# Epoch 41: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 706ms/step - loss: 0.0545 - val_loss: 2.6611
# Epoch 42/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0517
# Epoch 42: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 710ms/step - loss: 0.0517 - val_loss: 2.7121
# Epoch 43/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0472
# Epoch 43: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 781ms/step - loss: 0.0472 - val_loss: 2.7753
# Epoch 44/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0641
# Epoch 44: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 719ms/step - loss: 0.0641 - val_loss: 2.6182
# Epoch 45/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0556
# Epoch 45: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 870ms/step - loss: 0.0556 - val_loss: 2.7522
# Epoch 46/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0406
# Epoch 46: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 858ms/step - loss: 0.0406 - val_loss: 2.8530
# Epoch 47/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 47: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 728ms/step - loss: 0.0364 - val_loss: 2.7883
# Epoch 48/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0393
# Epoch 48: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 780ms/step - loss: 0.0393 - val_loss: 2.7964
# Epoch 49/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0376
# Epoch 49: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 817ms/step - loss: 0.0376 - val_loss: 2.8171
# Epoch 50/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0379
# Epoch 50: val_loss did not improve from 1.71053
# 8/8 [==============================] - 7s 908ms/step - loss: 0.0379 - val_loss: 2.7873
# Epoch 51/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0293
# Epoch 51: val_loss did not improve from 1.71053
# 8/8 [==============================] - 6s 755ms/step - loss: 0.0293 - val_loss: 2.8049

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)

import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')
# Out:
# 3/3 [==============================] - 2s 126ms/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      1.00      0.89        67
#      Clase 1       0.00      0.00      0.00        17
#
#     accuracy                           0.80        84
#    macro avg       0.40      0.50      0.44        84
# weighted avg       0.64      0.80      0.71        84
#
# Test set AUC Score after fine-tuning: 0.5741878841088673
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 11/11 [==============================] - 2s 135ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      0.98      0.88       265
#      Clase 1       0.50      0.09      0.15        70
#
#     accuracy                           0.79       335
#    macro avg       0.65      0.53      0.51       335
# weighted avg       0.74      0.79      0.73       335
#
# Train set AUC Score after fine-tuning: 0.6893800539083559

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image
import os

# Generar predicciones para las imágenes en el conjunto de prueba
predictions_test = model.predict(test_generator)
probabilities_test = predictions_test.flatten()

# Obtener los nombres de archivo y etiquetas correspondientes a las imágenes de prueba
filenames_test = test_generator.filenames
labels_test = test_generator.classes

# Crear una función para mostrar las imágenes con el nombre de archivo y la probabilidad
def plot_image_with_probability(filenames, probabilities, labels, directory, num_images=10):
    plt.figure(figsize=(15, 40))  # Tamaño ajustado para una mejor visualización
    count = 0
    for i in range(len(filenames)):
        if count >= num_images:
            break
        if labels[i] == 1 or probabilities[i] > 0.5:  # Mostrar imágenes etiquetadas como sospechosas o con alta probabilidad
            img_path = os.path.join(directory, filenames[i])
            img = image.load_img(img_path, target_size=(224, 224))

            # Mostrar imagen
            plt.subplot(num_images, 2, 2 * count + 1)
            plt.imshow(img)
            plt.title(f"File: {filenames[i]}")
            plt.axis('off')

            # Mostrar gráfica de probabilidad
            plt.subplot(num_images, 2, 2 * count + 2)
            plt.bar(['Sano', 'Sospechoso'], [1 - probabilities[i], probabilities[i]], color=['green', 'red'])
            plt.ylim([0, 1])
            plt.title(f"Probability: {probabilities[i]:.2f}")

            count += 1

    plt.tight_layout()
    plt.show()

# Visualizar las primeras 10 imágenes del conjunto de prueba con sus probabilidades
plot_image_with_probability(filenames_test, probabilities_test, labels_test, directorio_imagenes, num_images=10)
# Out:
# 3/3 [==============================] - 0s 124ms/step
