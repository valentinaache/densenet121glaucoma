# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True,
    channel_shift_range=10.0,
    validation_split=0.2
)


test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.keras"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.7561
# Epoch 1: val_loss improved from inf to 1.85936, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - loss: 0.7450 - val_loss: 1.8594
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3186
# Epoch 2: val_loss improved from 1.85936 to 1.31812, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 0.3200 - val_loss: 1.3181
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.3006
# Epoch 3: val_loss did not improve from 1.31812
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 0.2984 - val_loss: 2.0321
# Epoch 4/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.3013
# Epoch 4: val_loss did not improve from 1.31812
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - loss: 0.2941 - val_loss: 2.2395
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.2627
# Epoch 5: val_loss did not improve from 1.31812
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.2619 - val_loss: 1.7825
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1920
# Epoch 6: val_loss did not improve from 1.31812
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.1941 - val_loss: 1.4989
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1556
# Epoch 7: val_loss improved from 1.31812 to 1.11319, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - loss: 0.1585 - val_loss: 1.1132
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.1942
# Epoch 8: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.1924 - val_loss: 1.5403
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1460
# Epoch 9: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.1453 - val_loss: 1.4814
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1116
# Epoch 10: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.1132 - val_loss: 1.2776
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1370
# Epoch 11: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.1372 - val_loss: 1.2183
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1351
# Epoch 12: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - loss: 0.1336 - val_loss: 2.0321
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.1084
# Epoch 13: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.1066 - val_loss: 2.0757
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0811
# Epoch 14: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 0.0818 - val_loss: 1.4447
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0856
# Epoch 15: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0853 - val_loss: 1.8674
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0575
# Epoch 16: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.0583 - val_loss: 2.5537
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0366
# Epoch 17: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - loss: 0.0387 - val_loss: 1.7848
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0674
# Epoch 18: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0663 - val_loss: 2.2086
# Epoch 19/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0522
# Epoch 19: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0533 - val_loss: 2.4879
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0479
# Epoch 20: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0477 - val_loss: 3.0430
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0407
# Epoch 21: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 0.0406 - val_loss: 2.9695
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0605
# Epoch 22: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 0.0593 - val_loss: 3.1317
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0292
# Epoch 23: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0295 - val_loss: 2.1033
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0349
# Epoch 24: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0350 - val_loss: 2.3730
# Epoch 25/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0284
# Epoch 25: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - loss: 0.0288 - val_loss: 2.6083
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0257
# Epoch 26: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0254 - val_loss: 3.4561
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0201
# Epoch 27: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.0202 - val_loss: 2.9418
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0196
# Epoch 28: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0194 - val_loss: 2.6387
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0168
# Epoch 29: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0172 - val_loss: 3.5252
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0216
# Epoch 30: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 0.0214 - val_loss: 3.5837
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0157
# Epoch 31: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0159 - val_loss: 2.5173
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0219
# Epoch 32: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - loss: 0.0219 - val_loss: 2.9376
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0197
# Epoch 33: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0193 - val_loss: 3.4390
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0139
# Epoch 34: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.0137 - val_loss: 3.0223
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0137
# Epoch 35: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0134 - val_loss: 3.2548
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0101
# Epoch 36: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0103 - val_loss: 3.4481
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0111
# Epoch 37: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0110 - val_loss: 4.0504
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0130
# Epoch 38: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0129 - val_loss: 2.8730
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0084
# Epoch 39: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0084 - val_loss: 3.4598
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0216
# Epoch 40: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 0.0209 - val_loss: 3.7786
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0107
# Epoch 41: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.0106 - val_loss: 3.6335
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0070
# Epoch 42: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 0.0072 - val_loss: 4.2686
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0085
# Epoch 43: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0084 - val_loss: 3.4093
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0070
# Epoch 44: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.0068 - val_loss: 3.7657
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0041
# Epoch 45: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.0043 - val_loss: 3.1740
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0067
# Epoch 46: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.0067 - val_loss: 3.8848
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0049
# Epoch 47: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 0.0049 - val_loss: 3.1466
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0048
# Epoch 48: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 0.0048 - val_loss: 3.9998
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0045
# Epoch 49: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0045 - val_loss: 4.1627
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0043
# Epoch 50: val_loss did not improve from 1.11319
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0043 - val_loss: 3.8200

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.keras")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.000001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.keras"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8774
# Epoch 1: val_loss improved from inf to 0.94709, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 269s 14s/step - loss: 0.8635 - val_loss: 0.9471
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - loss: 0.6737
# Epoch 2: val_loss did not improve from 0.94709
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 53s 346ms/step - loss: 0.6818 - val_loss: 1.0104
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.7126
# Epoch 3: val_loss improved from 0.94709 to 0.90594, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 518ms/step - loss: 0.7153 - val_loss: 0.9059
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - loss: 0.6012
# Epoch 4: val_loss did not improve from 0.90594
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 309ms/step - loss: 0.6064 - val_loss: 0.9109
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - loss: 0.6722
# Epoch 5: val_loss improved from 0.90594 to 0.87695, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 568ms/step - loss: 0.6674 - val_loss: 0.8770
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.7261
# Epoch 6: val_loss improved from 0.87695 to 0.79686, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 536ms/step - loss: 0.7158 - val_loss: 0.7969
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.4754
# Epoch 7: val_loss did not improve from 0.79686
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - loss: 0.4831 - val_loss: 0.8737
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - loss: 0.5946
# Epoch 8: val_loss did not improve from 0.79686
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - loss: 0.5880 - val_loss: 0.8882
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - loss: 0.5931
# Epoch 9: val_loss did not improve from 0.79686
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.5912 - val_loss: 0.8008
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.1908
# Epoch 53: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.1896 - val_loss: 1.4020
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.1694
# Epoch 54: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - loss: 0.1708 - val_loss: 1.3801
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.1515
# Epoch 55: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - loss: 0.1522 - val_loss: 1.2994
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.2089
# Epoch 56: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 309ms/step - loss: 0.2063 - val_loss: 1.4662
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - loss: 0.1955
# Epoch 57: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - loss: 0.1935 - val_loss: 1.3309
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 0.2000
# Epoch 58: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 366ms/step - loss: 0.1962 - val_loss: 1.3361
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.1543
# Epoch 59: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 312ms/step - loss: 0.1545 - val_loss: 1.4067
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - loss: 0.1452
# Epoch 60: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.1480 - val_loss: 1.4106
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - loss: 0.1498
# Epoch 61: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - loss: 0.1499 - val_loss: 1.4407
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.1517
# Epoch 62: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - loss: 0.1521 - val_loss: 1.3515
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - loss: 0.1445
# Epoch 63: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.1450 - val_loss: 1.5478
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 0.2199
# Epoch 64: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 370ms/step - loss: 0.2153 - val_loss: 1.5165
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - loss: 0.1400
# Epoch 65: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.1422 - val_loss: 1.4821
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.1441
# Epoch 66: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 309ms/step - loss: 0.1438 - val_loss: 1.4730
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 0.1485
# Epoch 67: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 353ms/step - loss: 0.1483 - val_loss: 1.5438
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 0.1229
# Epoch 68: val_loss did not improve from 0.68157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - loss: 0.1239 - val_loss: 1.5369

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator, verbose=1)
y_test = test_generator.classes


thresholds = np.arange(0.1, 1.0, 0.1)
best_threshold = 0.5
best_f1 = 0

for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    f1 = f1_score(y_test, predicted_classes_test)
    precision = precision_score(y_test, predicted_classes_test)
    recall = recall_score(y_test, predicted_classes_test)

    print(f'Threshold: {threshold:.2f}')
    print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}\n')


    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f'Mejor threshold: {best_threshold} con F1 Score: {best_f1}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step
# Threshold: 0.10
# Precision: 0.2125, Recall: 1.0000, F1 Score: 0.3505
#
# Threshold: 0.20
# Precision: 0.2329, Recall: 1.0000, F1 Score: 0.3778
#
# Threshold: 0.30
# Precision: 0.2121, Recall: 0.8235, F1 Score: 0.3373
#
# Threshold: 0.40
# Precision: 0.2143, Recall: 0.7059, F1 Score: 0.3288
#
# Threshold: 0.50
# Precision: 0.2195, Recall: 0.5294, F1 Score: 0.3103
#
# Threshold: 0.60
# Precision: 0.2500, Recall: 0.4706, F1 Score: 0.3265
#
# Threshold: 0.70
# Precision: 0.2857, Recall: 0.3529, F1 Score: 0.3158
#
# Threshold: 0.80
# Precision: 0.3000, Recall: 0.1765, F1 Score: 0.2222
#
# Threshold: 0.90
# Precision: 0.3333, Recall: 0.0588, F1 Score: 0.1000
#
# Mejor threshold: 0.2 con F1 Score: 0.37777777777777777

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# Inicializar listas para almacenar las métricas
precisions = []
recalls = []
f1_scores = []

# Iterar sobre diferentes thresholds y calcular las métricas
for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    precisions.append(precision_score(y_test, predicted_classes_test))
    recalls.append(recall_score(y_test, predicted_classes_test))
    f1_scores.append(f1_score(y_test, predicted_classes_test))

# Graficar las métricas en función de los thresholds
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions, label='Precision')
plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, f1_scores, label='F1 Score')
plt.xlabel('Threshold')
plt.ylabel('Metric Value')
plt.title('Metrics vs. Threshold')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Evaluar con el mejor threshold encontrado
predicted_classes_test = (predictions_test >= best_threshold).astype(int)
print("Test set classification report with custom threshold:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))

precision = precision_score(y_test, predicted_classes_test)
recall = recall_score(y_test, predicted_classes_test)

print("Precision (Test Set, Class 1) with custom threshold:", precision)
print("Recall (Test Set, Class 1) with custom threshold:", recall)

auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score:", auc_score_test)
# Out:
# Test set classification report with custom threshold:
#               precision    recall  f1-score   support
#
#      Clase 0       1.00      0.16      0.28        67
#      Clase 1       0.23      1.00      0.38        17
#
#     accuracy                           0.33        84
#    macro avg       0.62      0.58      0.33        84
# weighted avg       0.84      0.33      0.30        84
#
# Precision (Test Set, Class 1) with custom threshold: 0.2328767123287671
# Recall (Test Set, Class 1) with custom threshold: 1.0
# Test set AUC Score: 0.5610184372256365

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, predictions_test)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# #RESULTADOS ANTERIORES

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.81      0.90      0.85        67
#      Clase 1       0.30      0.18      0.22        17
#
#     accuracy                           0.75        84
#    macro avg       0.56      0.54      0.54        84
# weighted avg       0.71      0.75      0.72        84
#
# Test set AUC Score after warmup: 0.6154521510096576
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.89      0.99      0.94       265
#      Clase 1       0.95      0.53      0.68        70
#
#     accuracy                           0.90       335
#    macro avg       0.92      0.76      0.81       335
# weighted avg       0.90      0.90      0.88       335
#
# Train set AUC Score after warmup: 0.8187601078167116

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.79      0.34      0.48        67
#      Clase 1       0.20      0.65      0.31        17
#
#     accuracy                           0.40        84
#    macro avg       0.50      0.50      0.39        84
# weighted avg       0.67      0.40      0.44        84
#
# Test set AUC Score after fine-tuning: 0.5171202809482002
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 528ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.91      0.52      0.66       265
#      Clase 1       0.31      0.81      0.45        70
#
#     accuracy                           0.58       335
#    macro avg       0.61      0.67      0.55       335
# weighted avg       0.79      0.58      0.62       335
#
# Train set AUC Score after fine-tuning: 0.7106738544474395

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')

# %%
from sklearn.metrics import precision_score, recall_score

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)
y_test = test_generator.classes

precision = precision_score(y_test, predicted_classes_test, average='binary', pos_label=1)
recall = recall_score(y_test, predicted_classes_test, average='binary', pos_label=1)

print("Precision (Test Set, Class 1):", precision)
print("Recall (Test Set, Class 1):", recall)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step
# Precision (Test Set, Class 1): 0.2
# Recall (Test Set, Class 1): 0.6470588235294118
