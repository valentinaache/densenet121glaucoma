# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet  import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    validation_split = 0.2
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.keras"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.7608
# Epoch 1: val_loss improved from inf to 0.68484, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 62s 4s/step - loss: 0.7571 - val_loss: 0.6848
# Epoch 2/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.6183
# Epoch 2: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.6115 - val_loss: 0.7733
# Epoch 3/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.5626
# Epoch 3: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.5530 - val_loss: 0.9104
# Epoch 4/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.4866
# Epoch 4: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.4878 - val_loss: 1.0339
# Epoch 5/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.4520
# Epoch 5: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - loss: 0.4561 - val_loss: 1.0874
# Epoch 6/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.5207
# Epoch 6: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - loss: 0.5136 - val_loss: 1.0879
# Epoch 7/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.5198
# Epoch 7: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.5076 - val_loss: 1.0777
# Epoch 8/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.4761
# Epoch 8: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.4755 - val_loss: 1.0429
# Epoch 9/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.4723
# Epoch 9: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - loss: 0.4694 - val_loss: 1.0806
# Epoch 10/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.5075
# Epoch 10: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.4984 - val_loss: 1.0144
# Epoch 11/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.5216
# Epoch 11: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.5087 - val_loss: 1.0520
# Epoch 12/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.3861
# Epoch 12: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.3997 - val_loss: 1.0725
# Epoch 13/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.5312
# Epoch 13: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.5155 - val_loss: 1.0356
# Epoch 14/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4283
# Epoch 14: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.4272 - val_loss: 1.0206
# Epoch 15/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4934
# Epoch 15: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.4832 - val_loss: 1.0667
# Epoch 16/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.4709
# Epoch 16: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.4610 - val_loss: 1.0557
# Epoch 17/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.3638
# Epoch 17: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.3762 - val_loss: 1.1084
# Epoch 18/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.5044
# Epoch 18: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.4889 - val_loss: 1.0375
# Epoch 19/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.3186
# Epoch 19: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.3390 - val_loss: 1.0969
# Epoch 20/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3886
# Epoch 20: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.3955 - val_loss: 1.0614
# Epoch 21/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4304
# Epoch 21: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.4265 - val_loss: 1.0558
# Epoch 22/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4176
# Epoch 22: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.4151 - val_loss: 1.0708
# Epoch 23/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3726
# Epoch 23: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.3763 - val_loss: 1.0705
# Epoch 24/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3974
# Epoch 24: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.3971 - val_loss: 1.0390
# Epoch 25/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3923
# Epoch 25: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.3940 - val_loss: 1.0614
# Epoch 26/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3692
# Epoch 26: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.3729 - val_loss: 1.0874
# Epoch 27/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3916
# Epoch 27: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.3924 - val_loss: 1.0885
# Epoch 28/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3405
# Epoch 28: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.3489 - val_loss: 1.0918
# Epoch 29/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4756
# Epoch 29: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.4593 - val_loss: 1.0415
# Epoch 30/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4403
# Epoch 30: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.4298 - val_loss: 1.0397
# Epoch 31/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3965
# Epoch 31: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.3957 - val_loss: 1.0864
# Epoch 32/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3175
# Epoch 32: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.3281 - val_loss: 1.1335
# Epoch 33/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.3497
# Epoch 33: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.3560 - val_loss: 1.0693
# Epoch 34/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3409
# Epoch 34: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.3483 - val_loss: 1.1061
# Epoch 35/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.3190
# Epoch 35: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.3330 - val_loss: 1.0551
# Epoch 36/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3651
# Epoch 36: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.3678 - val_loss: 1.0825
# Epoch 37/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.3838
# Epoch 37: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.3826 - val_loss: 1.0762
# Epoch 38/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.4947
# Epoch 38: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.4710 - val_loss: 1.0369
# Epoch 39/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3782
# Epoch 39: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.3754 - val_loss: 1.0605
# Epoch 40/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3955
# Epoch 40: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.3895 - val_loss: 1.0511
# Epoch 41/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.3310
# Epoch 41: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.3379 - val_loss: 1.0894
# Epoch 42/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.3113
# Epoch 42: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.3189 - val_loss: 1.0927
# Epoch 43/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.3711
# Epoch 43: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.3667 - val_loss: 1.1563
# Epoch 44/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.3879
# Epoch 44: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.3813 - val_loss: 1.1468
# Epoch 45/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.3294
# Epoch 45: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.3329 - val_loss: 1.1202
# Epoch 46/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3453
# Epoch 46: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.3461 - val_loss: 1.1403
# Epoch 47/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3991
# Epoch 47: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.3904 - val_loss: 1.1672
# Epoch 48/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.3791
# Epoch 48: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.3734 - val_loss: 1.1543
# Epoch 49/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.3210
# Epoch 49: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.3247 - val_loss: 1.1092
# Epoch 50/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.4428
# Epoch 50: val_loss did not improve from 0.68484
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.4238 - val_loss: 1.1043

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.keras")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.keras"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.5192
# Epoch 1: val_loss improved from inf to 2.51376, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 262s 14s/step - loss: 0.5108 - val_loss: 2.5138
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.3212
# Epoch 2: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - loss: 0.3252 - val_loss: 3.9399
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.3851
# Epoch 3: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 267ms/step - loss: 0.3797 - val_loss: 4.7642
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.2577
# Epoch 4: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 0.2558 - val_loss: 5.2596
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.1964
# Epoch 5: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 268ms/step - loss: 0.1933 - val_loss: 5.1368
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1478
# Epoch 6: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - loss: 0.1478 - val_loss: 5.1549
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.1228
# Epoch 7: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - loss: 0.1229 - val_loss: 5.3937
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0980
# Epoch 8: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 0.0992 - val_loss: 5.4630
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0625
# Epoch 9: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - loss: 0.0622 - val_loss: 5.1115
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0688
# Epoch 10: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 264ms/step - loss: 0.0676 - val_loss: 5.4013
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0490
# Epoch 11: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - loss: 0.0520 - val_loss: 6.0575
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0528
# Epoch 12: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - loss: 0.0517 - val_loss: 6.0525
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0359
# Epoch 13: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - loss: 0.0360 - val_loss: 6.4933
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0175
# Epoch 14: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 0.0174 - val_loss: 6.9332
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0074
# Epoch 15: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 267ms/step - loss: 0.0088 - val_loss: 6.8519
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0122
# Epoch 16: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - loss: 0.0122 - val_loss: 6.0173
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.0222
# Epoch 17: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - loss: 0.0240 - val_loss: 5.9986
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1008
# Epoch 18: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 0.0994 - val_loss: 4.8571
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.0431
# Epoch 19: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 273ms/step - loss: 0.0443 - val_loss: 4.4293
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0739
# Epoch 20: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - loss: 0.0727 - val_loss: 5.0686
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.0880
# Epoch 21: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - loss: 0.0863 - val_loss: 5.6184
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0292
# Epoch 22: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 267ms/step - loss: 0.0301 - val_loss: 5.6368
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0250
# Epoch 23: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - loss: 0.0246 - val_loss: 5.6574
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0146
# Epoch 24: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - loss: 0.0149 - val_loss: 5.0062
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0245
# Epoch 25: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - loss: 0.0248 - val_loss: 4.9680
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0115
# Epoch 26: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 0.0115 - val_loss: 6.0471
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0033
# Epoch 27: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 0.0033 - val_loss: 6.4539
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0200
# Epoch 28: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - loss: 0.0194 - val_loss: 6.8982
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0019
# Epoch 29: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - loss: 0.0019 - val_loss: 6.8855
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0047
# Epoch 30: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 0.0048 - val_loss: 6.3039
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0037
# Epoch 31: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 0.0040 - val_loss: 6.0642
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0011
# Epoch 32: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 0.0012 - val_loss: 5.7325
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.0049
# Epoch 33: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - loss: 0.0048 - val_loss: 6.0235
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0026
# Epoch 34: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - loss: 0.0026 - val_loss: 6.1252
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.0081
# Epoch 35: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - loss: 0.0079 - val_loss: 6.3495
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 9.3552e-04
# Epoch 36: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - loss: 0.0010 - val_loss: 5.9775
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0019
# Epoch 37: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - loss: 0.0019 - val_loss: 5.8779
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0010
# Epoch 38: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 275ms/step - loss: 0.0011 - val_loss: 5.5125
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.0029
# Epoch 39: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - loss: 0.0028 - val_loss: 5.3148
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0022
# Epoch 40: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 0.0021 - val_loss: 5.6123
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 7.4494e-04
# Epoch 41: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 7.5018e-04 - val_loss: 5.4752
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 9.6014e-04
# Epoch 42: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - loss: 9.2045e-04 - val_loss: 5.4284
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 5.1875e-04
# Epoch 43: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - loss: 5.4142e-04 - val_loss: 5.2320
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 5.4471e-04
# Epoch 44: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 5.5290e-04 - val_loss: 5.2107
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 2.2418e-04
# Epoch 45: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - loss: 2.3259e-04 - val_loss: 5.1724
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 2.1605e-04
# Epoch 46: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 268ms/step - loss: 2.1686e-04 - val_loss: 5.2607
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 6.3685e-04
# Epoch 47: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 6.1956e-04 - val_loss: 5.1579
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 9.0896e-04
# Epoch 48: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - loss: 8.8017e-04 - val_loss: 5.1720
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 9.1684e-04
# Epoch 49: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - loss: 8.7592e-04 - val_loss: 5.0588
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 9.3172e-04
# Epoch 50: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - loss: 8.8110e-04 - val_loss: 5.0701
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0387
# Epoch 51: val_loss did not improve from 2.51376
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - loss: 0.0390 - val_loss: 4.0929

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator, verbose=1)
y_test = test_generator.classes


thresholds = np.arange(0.1, 1.0, 0.1)
best_threshold = 0.5
best_f1 = 0

for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    f1 = f1_score(y_test, predicted_classes_test)
    precision = precision_score(y_test, predicted_classes_test)
    recall = recall_score(y_test, predicted_classes_test)

    print(f'Threshold: {threshold:.2f}')
    print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}\n')


    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f'Mejor threshold: {best_threshold} con F1 Score: {best_f1}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step
# Threshold: 0.10
# Precision: 0.3333, Recall: 0.0588, F1 Score: 0.1000
#
# Threshold: 0.20
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.30
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.40
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.50
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.60
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.70
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.80
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.90
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Mejor threshold: 0.1 con F1 Score: 0.1
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# Inicializar listas para almacenar las métricas
precisions = []
recalls = []
f1_scores = []

# Iterar sobre diferentes thresholds y calcular las métricas
for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    precisions.append(precision_score(y_test, predicted_classes_test))
    recalls.append(recall_score(y_test, predicted_classes_test))
    f1_scores.append(f1_score(y_test, predicted_classes_test))

# Graficar las métricas en función de los thresholds
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions, label='Precision')
plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, f1_scores, label='F1 Score')
plt.xlabel('Threshold')
plt.ylabel('Metric Value')
plt.title('Metrics vs. Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Evaluar con el mejor threshold encontrado
predicted_classes_test = (predictions_test >= best_threshold).astype(int)
print("Test set classification report with custom threshold:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))

precision = precision_score(y_test, predicted_classes_test)
recall = recall_score(y_test, predicted_classes_test)

print("Precision (Test Set, Class 1) with custom threshold:", precision)
print("Recall (Test Set, Class 1) with custom threshold:", recall)

auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score:", auc_score_test)
# Out:
# Test set classification report with custom threshold:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      0.97      0.88        67
#      Clase 1       0.33      0.06      0.10        17
#
#     accuracy                           0.79        84
#    macro avg       0.57      0.51      0.49        84
# weighted avg       0.71      0.79      0.72        84
#
# Precision (Test Set, Class 1) with custom threshold: 0.3333333333333333
# Recall (Test Set, Class 1) with custom threshold: 0.058823529411764705
# Test set AUC Score: 0.35294117647058826

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, predictions_test)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# #RESULTADOS ANTERIORES

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.79      0.87      0.83        67
#      Clase 1       0.18      0.12      0.14        17
#
#     accuracy                           0.71        84
#    macro avg       0.49      0.49      0.49        84
# weighted avg       0.67      0.71      0.69        84
#
# Test set AUC Score after warmup: 0.5689201053555751
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.84      0.93      0.88       265
#      Clase 1       0.55      0.31      0.40        70
#
#     accuracy                           0.80       335
#    macro avg       0.69      0.62      0.64       335
# weighted avg       0.78      0.80      0.78       335
#
# Train set AUC Score after warmup: 0.683989218328841

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      1.00      0.89        67
#      Clase 1       0.00      0.00      0.00        17
#
#     accuracy                           0.80        84
#    macro avg       0.40      0.50      0.44        84
# weighted avg       0.64      0.80      0.71        84
#
# Test set AUC Score after fine-tuning: 0.5399473222124671
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 431ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.79      1.00      0.88       265
#      Clase 1       0.00      0.00      0.00        70
#
#     accuracy                           0.79       335
#    macro avg       0.40      0.50      0.44       335
# weighted avg       0.63      0.79      0.70       335
#
# Train set AUC Score after fine-tuning: 0.5851212938005391
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')

# %%
from sklearn.metrics import precision_score, recall_score

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)
y_test = test_generator.classes

precision = precision_score(y_test, predicted_classes_test, average='binary', pos_label=1)
recall = recall_score(y_test, predicted_classes_test, average='binary', pos_label=1)

print("Precision (Test Set, Class 1):", precision)
print("Recall (Test Set, Class 1):", recall)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Precision (Test Set, Class 1): 0.0
# Recall (Test Set, Class 1): 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
