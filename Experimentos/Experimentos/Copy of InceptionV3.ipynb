# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]

dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])


patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedShuffleSplit


# Preparar los generadores de datos (esto permanece igual)
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1.0 / 255,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1.0 / 255
)

# Convertir 'Diagnosis' a tipo cadena
train_df['Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df['Diagnosis'] = test_df['Diagnosis'].astype(str)

train_data = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(299, 299),
    batch_size=20,
    class_mode='binary'
)

test_data = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(299, 299),
    batch_size=32,
    class_mode='binary'
)

valid_data = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(299, 299),
    batch_size=32,
    class_mode='binary'
)

# Configuración de los experimentos con diferentes tasas de aprendizaje
learning_rates = [0.001, 0.0001, 0.00001, 0.000001, 0.000001]

# Resultados para cada experimento
results = []

for lr in learning_rates:
    print(f"\n\n--- Experimento con learning rate = {lr} ---\n")

    # Base del modelo InceptionV3
    input_tensor = Input(shape=(299, 299, 3))
    base_model = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=False, pooling='avg')

    # Añadir capas superiores
    x = base_model.output
    x = Dense(2048, activation='relu')(x)
    predictions = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    # Warm-Up (entrenar solo capas superiores)
    for layer in base_model.layers:
        layer.trainable = False

    model.compile(optimizer=Adam(learning_rate=lr), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])

    checkpoint = ModelCheckpoint(f'best_model_warmup_lr_{lr}.keras', monitor='val_auc', save_best_only=True, mode='min', verbose=1)
    early_stop = EarlyStopping(monitor='val_auc', patience=10, restore_best_weights=True, mode='min')

    print("Inicio de Warm-Up Training...\n")
    warmup_history = model.fit(
        train_data,
        validation_data=valid_data,
        epochs=10,  # Por ejemplo, entrenamos por 10 épocas antes de hacer fine-tuning
        callbacks=[checkpoint, early_stop]
    )

    # Fine-Tuning (descongelar todas las capas)
    for layer in base_model.layers:
        layer.trainable = True

    model.compile(optimizer=Adam(learning_rate=lr/10), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])  # Reducir el LR para fine-tuning
    checkpoint = ModelCheckpoint(f'best_model_finetune_lr_{lr}.keras', monitor='val_auc', save_best_only=True, mode='min', verbose=1)

    print("Inicio de Fine-Tuning Training...\n")
    finetune_history = model.fit(
        train_data,
        validation_data=valid_data,
        epochs=50,  # Añadimos más épocas para el fine-tuning
        callbacks=[checkpoint, early_stop]
    )

    # Evaluación final en el conjunto de prueba
    evaluation = model.evaluate(test_data)
    print(f"Test Loss: {evaluation[0]}, Test Accuracy: {evaluation[1]}, Test AUC: {evaluation[2]}")

    # Guardar los resultados del experimento
    results.append({
        'learning_rate': lr,
        'test_loss': evaluation[0],
        'test_accuracy': evaluation[1],
        'test_auc': evaluation[2]
    })

    # Predicciones y AUC en el conjunto de entrenamiento
    y_train = train_data.classes
    predictions_train = model.predict(train_data, steps=len(train_data), verbose=1)
    predicted_classes_train = np.round(predictions_train).astype(int)
    print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))

    auc_score_train = roc_auc_score(y_train, predictions_train)
    print(f"AUC Score en entrenamiento: {auc_score_train}")

# Mostrar todos los resultados al final de los 5 experimentos
for result in results:
    print(f"Learning Rate: {result['learning_rate']}, Test Loss: {result['test_loss']}, Test Accuracy: {result['test_accuracy']}, Test AUC: {result['test_auc']}")
# Out:
# Found 335 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# <ipython-input-5-ec9c0e2dfa45>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Diagnosis'] = train_df['Diagnosis'].astype(str)
# <ipython-input-5-ec9c0e2dfa45>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Diagnosis'] = test_df['Diagnosis'].astype(str)
# --- Experimento con learning rate = 0.001 ---
#
# Inicio de Warm-Up Training...
#
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - AUC: 0.4672 - accuracy: 0.7463 - loss: 0.9355 - val_AUC: 0.6067 - val_accuracy: 0.7976 - val_loss: 0.8053
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: AUC,accuracy,loss,val_AUC,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 302ms/step - AUC: 0.4991 - accuracy: 0.7066 - loss: 0.7842 - val_AUC: 0.5764 - val_accuracy: 0.7976 - val_loss: 0.6696
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - AUC: 0.5628 - accuracy: 0.8025 - loss: 0.5714 - val_AUC: 0.5413 - val_accuracy: 0.7976 - val_loss: 0.5262
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 409ms/step - AUC: 0.4730 - accuracy: 0.7597 - loss: 0.5904 - val_AUC: 0.5329 - val_accuracy: 0.7976 - val_loss: 0.5021
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 303ms/step - AUC: 0.5279 - accuracy: 0.7933 - loss: 0.5307 - val_AUC: 0.5316 - val_accuracy: 0.7976 - val_loss: 0.5138
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 304ms/step - AUC: 0.4868 - accuracy: 0.7365 - loss: 0.6447 - val_AUC: 0.5566 - val_accuracy: 0.7976 - val_loss: 0.5490
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 402ms/step - AUC: 0.5398 - accuracy: 0.7975 - loss: 0.5458 - val_AUC: 0.5263 - val_accuracy: 0.7976 - val_loss: 0.5023
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - AUC: 0.5453 - accuracy: 0.8000 - loss: 0.5155 - val_AUC: 0.5246 - val_accuracy: 0.7976 - val_loss: 0.5257
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - AUC: 0.5372 - accuracy: 0.7984 - loss: 0.5143 - val_AUC: 0.5316 - val_accuracy: 0.7976 - val_loss: 0.5059
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 394ms/step - AUC: 0.5391 - accuracy: 0.7586 - loss: 0.5519 - val_AUC: 0.5474 - val_accuracy: 0.7976 - val_loss: 0.5205
# Inicio de Fine-Tuning Training...
#
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 130s 3s/step - AUC: 0.5317 - accuracy: 0.7612 - loss: 0.5654 - val_AUC: 0.5145 - val_accuracy: 0.7976 - val_loss: 1.0957
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 56s 419ms/step - AUC: 0.8271 - accuracy: 0.7993 - loss: 0.4233 - val_AUC: 0.5654 - val_accuracy: 0.7976 - val_loss: 0.6648
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 422ms/step - AUC: 0.9501 - accuracy: 0.8922 - loss: 0.2545 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 0.9947
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 445ms/step - AUC: 0.9844 - accuracy: 0.9241 - loss: 0.1527 - val_AUC: 0.5382 - val_accuracy: 0.7976 - val_loss: 1.0637
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 467ms/step - AUC: 0.9857 - accuracy: 0.9414 - loss: 0.1377 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 1.4176
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - AUC: 0.9821 - accuracy: 0.9325 - loss: 0.1387 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 2.1594
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 488ms/step - AUC: 0.9895 - accuracy: 0.9485 - loss: 0.1094 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 1.3830
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 416ms/step - AUC: 0.9281 - accuracy: 0.9566 - loss: 0.1207 - val_AUC: 0.4925 - val_accuracy: 0.7976 - val_loss: 0.7462
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 420ms/step - AUC: 0.9947 - accuracy: 0.9752 - loss: 0.0779 - val_AUC: 0.5228 - val_accuracy: 0.7976 - val_loss: 0.6041
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 436ms/step - AUC: 0.9970 - accuracy: 0.9618 - loss: 0.0686 - val_AUC: 0.4991 - val_accuracy: 0.7976 - val_loss: 0.7118
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 470ms/step - AUC: 0.9977 - accuracy: 0.9847 - loss: 0.0523 - val_AUC: 0.5487 - val_accuracy: 0.7976 - val_loss: 0.9434
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - AUC: 0.9986 - accuracy: 0.9920 - loss: 0.0359 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 1.3574
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 415ms/step - AUC: 0.9990 - accuracy: 0.9971 - loss: 0.0289 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 1.6597
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 466ms/step - AUC: 0.9999 - accuracy: 0.9886 - loss: 0.0280 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 3.6550
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 501ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0076 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 5.3586
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 438ms/step - AUC: 0.9995 - accuracy: 0.9888 - loss: 0.0207 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 3.7064
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 416ms/step - AUC: 0.9999 - accuracy: 0.9978 - loss: 0.0168 - val_AUC: 0.5294 - val_accuracy: 0.7976 - val_loss: 1.3676
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 544ms/step - AUC: 0.9782 - accuracy: 0.9835 - loss: 0.0916 - val_AUC: 0.5219 - val_accuracy: 0.7976 - val_loss: 1.3209
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 449ms/step - AUC: 0.9986 - accuracy: 0.9799 - loss: 0.0501 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 2.2116
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - AUC: 0.9984 - accuracy: 0.9805 - loss: 0.0546 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 1.9983
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 454ms/step - AUC: 0.9779 - accuracy: 0.9891 - loss: 0.0809 - val_AUC: 0.4763 - val_accuracy: 0.7976 - val_loss: 1.5127
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 427ms/step - AUC: 0.9981 - accuracy: 0.9838 - loss: 0.0434 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 1.4792
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 406ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0096 - val_AUC: 0.5193 - val_accuracy: 0.7976 - val_loss: 0.7444
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - AUC: 1.0000 - accuracy: 0.9928 - loss: 0.0141 - val_AUC: 0.5724 - val_accuracy: 0.7976 - val_loss: 0.5807
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 507ms/step - AUC: 1.0000 - accuracy: 0.9989 - loss: 0.0034 - val_AUC: 0.6168 - val_accuracy: 0.7976 - val_loss: 0.5114
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 415ms/step - AUC: 1.0000 - accuracy: 0.9990 - loss: 0.0040 - val_AUC: 0.6971 - val_accuracy: 0.7976 - val_loss: 0.4842
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 412ms/step - AUC: 0.9999 - accuracy: 0.9960 - loss: 0.0103 - val_AUC: 0.7853 - val_accuracy: 0.8214 - val_loss: 0.4278
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 439ms/step - AUC: 0.9999 - accuracy: 0.9924 - loss: 0.0167 - val_AUC: 0.8121 - val_accuracy: 0.8214 - val_loss: 0.4060
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 469ms/step - AUC: 0.9973 - accuracy: 0.9816 - loss: 0.0640 - val_AUC: 0.7287 - val_accuracy: 0.8214 - val_loss: 0.4413
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - AUC: 0.9991 - accuracy: 0.9899 - loss: 0.0312 - val_AUC: 0.8090 - val_accuracy: 0.8333 - val_loss: 0.4001
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 450ms/step - AUC: 0.9987 - accuracy: 0.9806 - loss: 0.0449 - val_AUC: 0.6747 - val_accuracy: 0.7143 - val_loss: 0.5178
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 431ms/step - AUC: 0.9984 - accuracy: 0.9762 - loss: 0.0603 - val_AUC: 0.6409 - val_accuracy: 0.7143 - val_loss: 0.5474
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 438ms/step - AUC: 0.9999 - accuracy: 0.9959 - loss: 0.0118 - val_AUC: 0.6958 - val_accuracy: 0.7381 - val_loss: 0.4868
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 510ms/step - AUC: 1.0000 - accuracy: 0.9971 - loss: 0.0094 - val_AUC: 0.7384 - val_accuracy: 0.5595 - val_loss: 0.6650
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 456ms/step - AUC: 0.9999 - accuracy: 0.9911 - loss: 0.0180 - val_AUC: 0.6962 - val_accuracy: 0.7143 - val_loss: 0.5234
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 428ms/step - AUC: 0.9996 - accuracy: 0.9933 - loss: 0.0204 - val_AUC: 0.6839 - val_accuracy: 0.6786 - val_loss: 0.5298
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 526ms/step - AUC: 1.0000 - accuracy: 0.9971 - loss: 0.0057 - val_AUC: 0.8099 - val_accuracy: 0.7857 - val_loss: 0.4348
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 424ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0081 - val_AUC: 0.8815 - val_accuracy: 0.8452 - val_loss: 0.3400
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 409ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0037 - val_AUC: 0.9025 - val_accuracy: 0.7976 - val_loss: 0.3892
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 477ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0024 - val_AUC: 0.8907 - val_accuracy: 0.7381 - val_loss: 0.4588
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 456ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 6.9845e-04 - val_AUC: 0.8951 - val_accuracy: 0.8095 - val_loss: 0.4327
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 466ms/step - AUC: 1.0000 - accuracy: 0.9993 - loss: 0.0040 - val_AUC: 0.9214 - val_accuracy: 0.7976 - val_loss: 0.2981
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 426ms/step - AUC: 1.0000 - accuracy: 0.9945 - loss: 0.0096 - val_AUC: 0.7919 - val_accuracy: 0.4762 - val_loss: 1.3805
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 420ms/step - AUC: 0.9880 - accuracy: 0.9945 - loss: 0.0673 - val_AUC: 0.7937 - val_accuracy: 0.5476 - val_loss: 0.9084
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 419ms/step - AUC: 0.9979 - accuracy: 0.9764 - loss: 0.0569 - val_AUC: 0.7704 - val_accuracy: 0.5833 - val_loss: 0.9577
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 475ms/step - AUC: 0.9995 - accuracy: 0.9878 - loss: 0.0407 - val_AUC: 0.7766 - val_accuracy: 0.6905 - val_loss: 0.9869
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 427ms/step - AUC: 0.9958 - accuracy: 0.9861 - loss: 0.0487 - val_AUC: 0.7994 - val_accuracy: 0.7024 - val_loss: 0.8121
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 426ms/step - AUC: 1.0000 - accuracy: 0.9884 - loss: 0.0187 - val_AUC: 0.7818 - val_accuracy: 0.5000 - val_loss: 1.3939
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 450ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0025 - val_AUC: 0.8073 - val_accuracy: 0.6429 - val_loss: 1.0650
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 508ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0030 - val_AUC: 0.8235 - val_accuracy: 0.7024 - val_loss: 0.9696
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - AUC: 0.8108 - accuracy: 0.7067 - loss: 0.9942
# Test Loss: 0.9695885181427002, Test Accuracy: 0.7023809552192688, Test AUC: 0.8235293626785278
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 805ms/step
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      0.69      0.74       265
#      Clase 1       0.24      0.36      0.28        70
#
#     accuracy                           0.62       335
#    macro avg       0.52      0.53      0.51       335
# weighted avg       0.68      0.62      0.65       335
#
# AUC Score en entrenamiento: 0.5279784366576818
#
#
# --- Experimento con learning rate = 0.0001 ---
#
# Inicio de Warm-Up Training...
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - AUC: 0.5018 - accuracy: 0.8094 - loss: 0.5385 - val_AUC: 0.5369 - val_accuracy: 0.7976 - val_loss: 0.5313
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: AUC,accuracy,loss,val_AUC,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 420ms/step - AUC: 0.4529 - accuracy: 0.7839 - loss: 0.5485 - val_AUC: 0.5474 - val_accuracy: 0.7976 - val_loss: 0.5136
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 300ms/step - AUC: 0.5266 - accuracy: 0.8001 - loss: 0.5042 - val_AUC: 0.5219 - val_accuracy: 0.7976 - val_loss: 0.5049
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 372ms/step - AUC: 0.4883 - accuracy: 0.7618 - loss: 0.5524 - val_AUC: 0.5536 - val_accuracy: 0.7976 - val_loss: 0.5078
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - AUC: 0.5403 - accuracy: 0.8030 - loss: 0.4951 - val_AUC: 0.5439 - val_accuracy: 0.7976 - val_loss: 0.5043
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 304ms/step - AUC: 0.5046 - accuracy: 0.7667 - loss: 0.5437 - val_AUC: 0.5347 - val_accuracy: 0.7976 - val_loss: 0.5039
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 299ms/step - AUC: 0.5289 - accuracy: 0.7805 - loss: 0.5294 - val_AUC: 0.5461 - val_accuracy: 0.7976 - val_loss: 0.5087
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 397ms/step - AUC: 0.5243 - accuracy: 0.7902 - loss: 0.5173 - val_AUC: 0.5386 - val_accuracy: 0.7976 - val_loss: 0.5023
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 319ms/step - AUC: 0.5444 - accuracy: 0.7559 - loss: 0.5571 - val_AUC: 0.5329 - val_accuracy: 0.7976 - val_loss: 0.5048
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 311ms/step - AUC: 0.4911 - accuracy: 0.7834 - loss: 0.5381 - val_AUC: 0.5211 - val_accuracy: 0.7976 - val_loss: 0.5057
# Inicio de Fine-Tuning Training...
#
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 128s 3s/step - AUC: 0.5861 - accuracy: 0.8313 - loss: 0.4572 - val_AUC: 0.5263 - val_accuracy: 0.7976 - val_loss: 0.5082
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 62s 424ms/step - AUC: 0.7229 - accuracy: 0.8281 - loss: 0.4314 - val_AUC: 0.4535 - val_accuracy: 0.7976 - val_loss: 0.5081
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 480ms/step - AUC: 0.7820 - accuracy: 0.7999 - loss: 0.4336 - val_AUC: 0.5294 - val_accuracy: 0.7976 - val_loss: 0.5075
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 518ms/step - AUC: 0.8182 - accuracy: 0.8177 - loss: 0.3981 - val_AUC: 0.5610 - val_accuracy: 0.7976 - val_loss: 0.5044
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 417ms/step - AUC: 0.8575 - accuracy: 0.7670 - loss: 0.4312 - val_AUC: 0.5939 - val_accuracy: 0.7976 - val_loss: 0.5096
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 504ms/step - AUC: 0.8810 - accuracy: 0.8023 - loss: 0.3861 - val_AUC: 0.5536 - val_accuracy: 0.7976 - val_loss: 0.5121
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 456ms/step - AUC: 0.8572 - accuracy: 0.8019 - loss: 0.4141 - val_AUC: 0.5053 - val_accuracy: 0.7976 - val_loss: 0.5034
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - AUC: 0.9068 - accuracy: 0.8589 - loss: 0.3276 - val_AUC: 0.4921 - val_accuracy: 0.7976 - val_loss: 0.5108
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 489ms/step - AUC: 0.9274 - accuracy: 0.8820 - loss: 0.3013 - val_AUC: 0.5751 - val_accuracy: 0.7976 - val_loss: 0.5089
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 425ms/step - AUC: 0.9490 - accuracy: 0.8789 - loss: 0.2898 - val_AUC: 0.4394 - val_accuracy: 0.7976 - val_loss: 0.5172
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 443ms/step - AUC: 0.9748 - accuracy: 0.9235 - loss: 0.2366 - val_AUC: 0.4254 - val_accuracy: 0.7976 - val_loss: 0.5069
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 428ms/step - AUC: 0.9489 - accuracy: 0.9046 - loss: 0.2452 - val_AUC: 0.5378 - val_accuracy: 0.7976 - val_loss: 0.5297
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 417ms/step - AUC: 0.9746 - accuracy: 0.9400 - loss: 0.2063 - val_AUC: 0.6795 - val_accuracy: 0.7976 - val_loss: 0.5072
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 426ms/step - AUC: 0.9962 - accuracy: 0.9546 - loss: 0.1705 - val_AUC: 0.6418 - val_accuracy: 0.7976 - val_loss: 0.4999
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 452ms/step - AUC: 0.9849 - accuracy: 0.9385 - loss: 0.1766 - val_AUC: 0.5562 - val_accuracy: 0.7976 - val_loss: 0.5011
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - AUC: 0.9875 - accuracy: 0.9526 - loss: 0.1674 - val_AUC: 0.6453 - val_accuracy: 0.7976 - val_loss: 0.5040
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 418ms/step - AUC: 0.9907 - accuracy: 0.9551 - loss: 0.1453 - val_AUC: 0.6304 - val_accuracy: 0.7976 - val_loss: 0.5011
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 460ms/step - AUC: 0.9932 - accuracy: 0.9311 - loss: 0.1442 - val_AUC: 0.6269 - val_accuracy: 0.7976 - val_loss: 0.4978
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 460ms/step - AUC: 0.9979 - accuracy: 0.9752 - loss: 0.1078 - val_AUC: 0.5382 - val_accuracy: 0.7976 - val_loss: 0.5266
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 501ms/step - AUC: 0.9989 - accuracy: 0.9872 - loss: 0.0770 - val_AUC: 0.4701 - val_accuracy: 0.7976 - val_loss: 0.5268
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 460ms/step - AUC: 0.9999 - accuracy: 0.9992 - loss: 0.0738 - val_AUC: 0.4991 - val_accuracy: 0.7976 - val_loss: 0.5198
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - AUC: 0.9998 - accuracy: 0.9905 - loss: 0.0601 - val_AUC: 0.5465 - val_accuracy: 0.7857 - val_loss: 0.5204
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 446ms/step - AUC: 0.9996 - accuracy: 0.9984 - loss: 0.0527 - val_AUC: 0.6150 - val_accuracy: 0.8095 - val_loss: 0.4891
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 506ms/step - AUC: 0.9987 - accuracy: 0.9893 - loss: 0.0553 - val_AUC: 0.5689 - val_accuracy: 0.7976 - val_loss: 0.4948
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 458ms/step - AUC: 0.9989 - accuracy: 0.9832 - loss: 0.0579 - val_AUC: 0.5509 - val_accuracy: 0.7976 - val_loss: 0.5068
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 410ms/step - AUC: 0.9995 - accuracy: 0.9859 - loss: 0.0473 - val_AUC: 0.4754 - val_accuracy: 0.7976 - val_loss: 0.5538
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 459ms/step - AUC: 0.9998 - accuracy: 0.9847 - loss: 0.0378 - val_AUC: 0.5140 - val_accuracy: 0.7976 - val_loss: 0.5552
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 414ms/step - AUC: 0.9998 - accuracy: 0.9868 - loss: 0.0450 - val_AUC: 0.4899 - val_accuracy: 0.7976 - val_loss: 0.5369
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 412ms/step - AUC: 1.0000 - accuracy: 0.9970 - loss: 0.0199 - val_AUC: 0.5299 - val_accuracy: 0.7262 - val_loss: 0.5623
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 422ms/step - AUC: 0.9999 - accuracy: 0.9979 - loss: 0.0461 - val_AUC: 0.5549 - val_accuracy: 0.7381 - val_loss: 0.5767
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 469ms/step - AUC: 0.9999 - accuracy: 0.9946 - loss: 0.0314 - val_AUC: 0.5799 - val_accuracy: 0.7262 - val_loss: 0.6274
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 418ms/step - AUC: 0.9993 - accuracy: 0.9939 - loss: 0.0355 - val_AUC: 0.6282 - val_accuracy: 0.7619 - val_loss: 0.6295
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 407ms/step - AUC: 0.9994 - accuracy: 0.9932 - loss: 0.0342 - val_AUC: 0.6550 - val_accuracy: 0.7976 - val_loss: 0.6520
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 475ms/step - AUC: 1.0000 - accuracy: 0.9977 - loss: 0.0168 - val_AUC: 0.7032 - val_accuracy: 0.8333 - val_loss: 0.5818
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 503ms/step - AUC: 0.9999 - accuracy: 0.9935 - loss: 0.0184 - val_AUC: 0.7436 - val_accuracy: 0.8095 - val_loss: 0.5376
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 467ms/step - AUC: 0.9997 - accuracy: 0.9881 - loss: 0.0307 - val_AUC: 0.7634 - val_accuracy: 0.8095 - val_loss: 0.5193
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 419ms/step - AUC: 1.0000 - accuracy: 0.9993 - loss: 0.0150 - val_AUC: 0.7656 - val_accuracy: 0.7857 - val_loss: 0.5186
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 455ms/step - AUC: 1.0000 - accuracy: 0.9959 - loss: 0.0160 - val_AUC: 0.7761 - val_accuracy: 0.8095 - val_loss: 0.5093
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0114 - val_AUC: 0.7976 - val_accuracy: 0.8333 - val_loss: 0.4818
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 476ms/step - AUC: 1.0000 - accuracy: 1.0000 - loss: 0.0205 - val_AUC: 0.8191 - val_accuracy: 0.8452 - val_loss: 0.4519
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 419ms/step - AUC: 0.9984 - accuracy: 0.9917 - loss: 0.0381 - val_AUC: 0.8095 - val_accuracy: 0.7857 - val_loss: 0.4808
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 419ms/step - AUC: 1.0000 - accuracy: 0.9986 - loss: 0.0128 - val_AUC: 0.8134 - val_accuracy: 0.8095 - val_loss: 0.5125
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 453ms/step - AUC: 1.0000 - accuracy: 0.9993 - loss: 0.0115 - val_AUC: 0.8446 - val_accuracy: 0.8095 - val_loss: 0.4857
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 467ms/step - AUC: 1.0000 - accuracy: 0.9963 - loss: 0.0154 - val_AUC: 0.8512 - val_accuracy: 0.8095 - val_loss: 0.4547
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 422ms/step - AUC: 1.0000 - accuracy: 0.9993 - loss: 0.0172 - val_AUC: 0.8560 - val_accuracy: 0.8095 - val_loss: 0.4362
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 414ms/step - AUC: 1.0000 - accuracy: 0.9919 - loss: 0.0151 - val_AUC: 0.8802 - val_accuracy: 0.8095 - val_loss: 0.3943
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 480ms/step - AUC: 0.9999 - accuracy: 0.9950 - loss: 0.0242 - val_AUC: 0.8687 - val_accuracy: 0.7976 - val_loss: 0.4116
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 502ms/step - AUC: 1.0000 - accuracy: 0.9975 - loss: 0.0085 - val_AUC: 0.8428 - val_accuracy: 0.7976 - val_loss: 0.4559
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 411ms/step - AUC: 0.9999 - accuracy: 0.9991 - loss: 0.0090 - val_AUC: 0.8411 - val_accuracy: 0.7976 - val_loss: 0.4491
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 424ms/step - AUC: 1.0000 - accuracy: 0.9971 - loss: 0.0120 - val_AUC: 0.8639 - val_accuracy: 0.8214 - val_loss: 0.4042
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - AUC: 0.8463 - accuracy: 0.8013 - loss: 0.4465
# Test Loss: 0.4041951596736908, Test Accuracy: 0.8214285969734192, Test AUC: 0.863915741443634
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 794ms/step
#               precision    recall  f1-score   support
#
#      Clase 0       0.79      0.79      0.79       265
#      Clase 1       0.20      0.20      0.20        70
#
#     accuracy                           0.67       335
#    macro avg       0.49      0.49      0.49       335
# weighted avg       0.67      0.67      0.67       335
#
# AUC Score en entrenamiento: 0.5456064690026954
#
#
# --- Experimento con learning rate = 1e-05 ---
#
# Inicio de Warm-Up Training...
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - AUC: 0.5679 - accuracy: 0.4175 - loss: 0.7109 - val_AUC: 0.4543 - val_accuracy: 0.7976 - val_loss: 0.5701
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: AUC,accuracy,loss,val_AUC,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 318ms/step - AUC: 0.5792 - accuracy: 0.7576 - loss: 0.5685 - val_AUC: 0.5856 - val_accuracy: 0.7976 - val_loss: 0.5086
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 361ms/step - AUC: 0.5110 - accuracy: 0.7985 - loss: 0.5059 - val_AUC: 0.4925 - val_accuracy: 0.7976 - val_loss: 0.5032
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 334ms/step - AUC: 0.5152 - accuracy: 0.8039 - loss: 0.4949 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 0.5033
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 298ms/step - AUC: 0.4930 - accuracy: 0.7648 - loss: 0.5500 - val_AUC: 0.5689 - val_accuracy: 0.7976 - val_loss: 0.5033
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 13s 488ms/step - AUC: 0.5675 - accuracy: 0.7814 - loss: 0.5249 - val_AUC: 0.5316 - val_accuracy: 0.7976 - val_loss: 0.5031
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 343ms/step - AUC: 0.5618 - accuracy: 0.7631 - loss: 0.5493 - val_AUC: 0.5391 - val_accuracy: 0.7976 - val_loss: 0.5033
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 316ms/step - AUC: 0.5548 - accuracy: 0.7870 - loss: 0.5169 - val_AUC: 0.5391 - val_accuracy: 0.7976 - val_loss: 0.5030
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - AUC: 0.5467 - accuracy: 0.8102 - loss: 0.4858 - val_AUC: 0.5092 - val_accuracy: 0.7976 - val_loss: 0.5029
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 329ms/step - AUC: 0.5593 - accuracy: 0.8210 - loss: 0.4712 - val_AUC: 0.5773 - val_accuracy: 0.7976 - val_loss: 0.5029
# Inicio de Fine-Tuning Training...
#
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 134s 4s/step - AUC: 0.5291 - accuracy: 0.8175 - loss: 0.4954 - val_AUC: 0.5404 - val_accuracy: 0.7976 - val_loss: 0.5039
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 539ms/step - AUC: 0.6095 - accuracy: 0.8046 - loss: 0.4919 - val_AUC: 0.4851 - val_accuracy: 0.7976 - val_loss: 0.5094
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 519ms/step - AUC: 0.5677 - accuracy: 0.7678 - loss: 0.5607 - val_AUC: 0.5558 - val_accuracy: 0.7976 - val_loss: 0.5028
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 476ms/step - AUC: 0.5978 - accuracy: 0.7852 - loss: 0.5204 - val_AUC: 0.5395 - val_accuracy: 0.7976 - val_loss: 0.5076
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 434ms/step - AUC: 0.5683 - accuracy: 0.7765 - loss: 0.5318 - val_AUC: 0.6330 - val_accuracy: 0.7976 - val_loss: 0.5040
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 539ms/step - AUC: 0.5950 - accuracy: 0.8104 - loss: 0.4759 - val_AUC: 0.5294 - val_accuracy: 0.7976 - val_loss: 0.5035
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 497ms/step - AUC: 0.5902 - accuracy: 0.7642 - loss: 0.5446 - val_AUC: 0.4622 - val_accuracy: 0.7976 - val_loss: 0.5046
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 13s 545ms/step - AUC: 0.7549 - accuracy: 0.8181 - loss: 0.4423 - val_AUC: 0.4741 - val_accuracy: 0.7976 - val_loss: 0.5086
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 428ms/step - AUC: 0.6846 - accuracy: 0.8045 - loss: 0.4718 - val_AUC: 0.4934 - val_accuracy: 0.7976 - val_loss: 0.5121
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 470ms/step - AUC: 0.7059 - accuracy: 0.7887 - loss: 0.4861 - val_AUC: 0.5101 - val_accuracy: 0.7976 - val_loss: 0.5243
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 427ms/step - AUC: 0.7244 - accuracy: 0.8196 - loss: 0.4442 - val_AUC: 0.5860 - val_accuracy: 0.7976 - val_loss: 0.5289
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 428ms/step - AUC: 0.7838 - accuracy: 0.8107 - loss: 0.4405 - val_AUC: 0.4785 - val_accuracy: 0.7976 - val_loss: 0.5328
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 526ms/step - AUC: 0.6879 - accuracy: 0.7829 - loss: 0.4953 - val_AUC: 0.4482 - val_accuracy: 0.7976 - val_loss: 0.5294
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 499ms/step - AUC: 0.6725 - accuracy: 0.7889 - loss: 0.4889 - val_AUC: 0.4192 - val_accuracy: 0.7976 - val_loss: 0.5302
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 412ms/step - AUC: 0.7699 - accuracy: 0.7905 - loss: 0.4664 - val_AUC: 0.5474 - val_accuracy: 0.7976 - val_loss: 0.5330
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 526ms/step - AUC: 0.7688 - accuracy: 0.7675 - loss: 0.4933 - val_AUC: 0.5092 - val_accuracy: 0.7976 - val_loss: 0.5333
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 448ms/step - AUC: 0.7544 - accuracy: 0.8056 - loss: 0.4524 - val_AUC: 0.4811 - val_accuracy: 0.7976 - val_loss: 0.5433
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 467ms/step - AUC: 0.7989 - accuracy: 0.8174 - loss: 0.4281 - val_AUC: 0.4969 - val_accuracy: 0.7976 - val_loss: 0.5647
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 415ms/step - AUC: 0.7086 - accuracy: 0.8302 - loss: 0.4179 - val_AUC: 0.4618 - val_accuracy: 0.7976 - val_loss: 0.5751
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 457ms/step - AUC: 0.7887 - accuracy: 0.7566 - loss: 0.5007 - val_AUC: 0.4438 - val_accuracy: 0.7976 - val_loss: 0.5919
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 509ms/step - AUC: 0.6743 - accuracy: 0.7946 - loss: 0.4839 - val_AUC: 0.4807 - val_accuracy: 0.7976 - val_loss: 0.6051
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 458ms/step - AUC: 0.7309 - accuracy: 0.8153 - loss: 0.4419 - val_AUC: 0.5057 - val_accuracy: 0.7976 - val_loss: 0.6242
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 414ms/step - AUC: 0.7371 - accuracy: 0.7900 - loss: 0.4674 - val_AUC: 0.5342 - val_accuracy: 0.7976 - val_loss: 0.6302
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 476ms/step - AUC: 0.8083 - accuracy: 0.7684 - loss: 0.4774 - val_AUC: 0.4723 - val_accuracy: 0.7976 - val_loss: 0.6231
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 455ms/step - AUC: 0.7841 - accuracy: 0.8123 - loss: 0.4314 - val_AUC: 0.4697 - val_accuracy: 0.7976 - val_loss: 0.6219
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 437ms/step - AUC: 0.8158 - accuracy: 0.7848 - loss: 0.4512 - val_AUC: 0.4021 - val_accuracy: 0.7976 - val_loss: 0.6016
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 467ms/step - AUC: 0.8288 - accuracy: 0.8145 - loss: 0.4173 - val_AUC: 0.4197 - val_accuracy: 0.7976 - val_loss: 0.5806
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 452ms/step - AUC: 0.8164 - accuracy: 0.7901 - loss: 0.4475 - val_AUC: 0.4658 - val_accuracy: 0.7976 - val_loss: 0.5420
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 442ms/step - AUC: 0.7862 - accuracy: 0.8013 - loss: 0.4429 - val_AUC: 0.4759 - val_accuracy: 0.7976 - val_loss: 0.5261
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 463ms/step - AUC: 0.8397 - accuracy: 0.7842 - loss: 0.4427 - val_AUC: 0.4333 - val_accuracy: 0.7976 - val_loss: 0.5172
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - AUC: 0.7825 - accuracy: 0.8033 - loss: 0.4394 - val_AUC: 0.4903 - val_accuracy: 0.7976 - val_loss: 0.5035
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 459ms/step - AUC: 0.8203 - accuracy: 0.7985 - loss: 0.4349 - val_AUC: 0.5097 - val_accuracy: 0.7976 - val_loss: 0.5053
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - AUC: 0.7801 - accuracy: 0.7737 - loss: 0.4738 - val_AUC: 0.5461 - val_accuracy: 0.7976 - val_loss: 0.5024
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 478ms/step - AUC: 0.8006 - accuracy: 0.7910 - loss: 0.4416 - val_AUC: 0.5707 - val_accuracy: 0.7976 - val_loss: 0.4990
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - AUC: 0.8240 - accuracy: 0.7635 - loss: 0.4646 - val_AUC: 0.4969 - val_accuracy: 0.7976 - val_loss: 0.5071
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 496ms/step - AUC: 0.8336 - accuracy: 0.8071 - loss: 0.4132 - val_AUC: 0.4965 - val_accuracy: 0.7976 - val_loss: 0.5074
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 468ms/step - AUC: 0.8388 - accuracy: 0.7817 - loss: 0.4408 - val_AUC: 0.5698 - val_accuracy: 0.7976 - val_loss: 0.4966
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - AUC: 0.8549 - accuracy: 0.7908 - loss: 0.4260 - val_AUC: 0.5641 - val_accuracy: 0.7976 - val_loss: 0.5002
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 459ms/step - AUC: 0.8098 - accuracy: 0.7966 - loss: 0.4330 - val_AUC: 0.5601 - val_accuracy: 0.7976 - val_loss: 0.5018
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 546ms/step - AUC: 0.8507 - accuracy: 0.7852 - loss: 0.4215 - val_AUC: 0.5685 - val_accuracy: 0.7976 - val_loss: 0.4998
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 476ms/step - AUC: 0.8162 - accuracy: 0.8041 - loss: 0.4151 - val_AUC: 0.5838 - val_accuracy: 0.7976 - val_loss: 0.4972
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 502ms/step - AUC: 0.8871 - accuracy: 0.7967 - loss: 0.4033 - val_AUC: 0.5742 - val_accuracy: 0.7976 - val_loss: 0.4972
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - AUC: 0.8464 - accuracy: 0.8026 - loss: 0.4087 - val_AUC: 0.5847 - val_accuracy: 0.7976 - val_loss: 0.4990
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 418ms/step - AUC: 0.8405 - accuracy: 0.7677 - loss: 0.4501 - val_AUC: 0.5847 - val_accuracy: 0.7976 - val_loss: 0.4992
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 523ms/step - AUC: 0.8440 - accuracy: 0.8156 - loss: 0.3918 - val_AUC: 0.6040 - val_accuracy: 0.7976 - val_loss: 0.4972
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 460ms/step - AUC: 0.8319 - accuracy: 0.7660 - loss: 0.4425 - val_AUC: 0.6264 - val_accuracy: 0.7976 - val_loss: 0.4929
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 455ms/step - AUC: 0.8407 - accuracy: 0.7923 - loss: 0.4146 - val_AUC: 0.6326 - val_accuracy: 0.7976 - val_loss: 0.4893
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 418ms/step - AUC: 0.8530 - accuracy: 0.7841 - loss: 0.4122 - val_AUC: 0.6435 - val_accuracy: 0.7976 - val_loss: 0.4874
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 439ms/step - AUC: 0.8666 - accuracy: 0.7921 - loss: 0.4072 - val_AUC: 0.6435 - val_accuracy: 0.7976 - val_loss: 0.4882
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 439ms/step - AUC: 0.8666 - accuracy: 0.7853 - loss: 0.4126 - val_AUC: 0.6330 - val_accuracy: 0.7857 - val_loss: 0.4890
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - AUC: 0.6461 - accuracy: 0.7796 - loss: 0.4957
# Test Loss: 0.4889616370201111, Test Accuracy: 0.7857142686843872, Test AUC: 0.6330114603042603
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 811ms/step
#               precision    recall  f1-score   support
#
#      Clase 0       0.79      1.00      0.88       265
#      Clase 1       0.00      0.00      0.00        70
#
#     accuracy                           0.79       335
#    macro avg       0.40      0.50      0.44       335
# weighted avg       0.63      0.79      0.70       335
#
# AUC Score en entrenamiento: 0.4954716981132075
#
#
# --- Experimento con learning rate = 1e-06 ---
#
# Inicio de Warm-Up Training...
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - AUC: 0.4955 - accuracy: 0.7992 - loss: 0.6289 - val_AUC: 0.5145 - val_accuracy: 0.7976 - val_loss: 0.6139
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: AUC,accuracy,loss,val_AUC,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 368ms/step - AUC: 0.4879 - accuracy: 0.8144 - loss: 0.6042 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 0.5958
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 309ms/step - AUC: 0.5108 - accuracy: 0.7930 - loss: 0.5940 - val_AUC: 0.5364 - val_accuracy: 0.7976 - val_loss: 0.5806
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 320ms/step - AUC: 0.4513 - accuracy: 0.8172 - loss: 0.5685 - val_AUC: 0.5606 - val_accuracy: 0.7976 - val_loss: 0.5677
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 366ms/step - AUC: 0.5196 - accuracy: 0.7844 - loss: 0.5724 - val_AUC: 0.6150 - val_accuracy: 0.7976 - val_loss: 0.5567
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 311ms/step - AUC: 0.5413 - accuracy: 0.7826 - loss: 0.5638 - val_AUC: 0.5996 - val_accuracy: 0.7976 - val_loss: 0.5474
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 319ms/step - AUC: 0.5174 - accuracy: 0.7696 - loss: 0.5647 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 0.5395
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 415ms/step - AUC: 0.5191 - accuracy: 0.7789 - loss: 0.5520 - val_AUC: 0.6242 - val_accuracy: 0.7976 - val_loss: 0.5329
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - AUC: 0.5647 - accuracy: 0.7812 - loss: 0.5447 - val_AUC: 0.5514 - val_accuracy: 0.7976 - val_loss: 0.5273
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 332ms/step - AUC: 0.5059 - accuracy: 0.8118 - loss: 0.5144 - val_AUC: 0.5000 - val_accuracy: 0.7976 - val_loss: 0.5225
# Inicio de Fine-Tuning Training...
#
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1456s 4s/step - AUC: 0.4491 - accuracy: 0.8116 - loss: 0.5177 - val_AUC: 0.5452 - val_accuracy: 0.7976 - val_loss: 0.5254
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 13s 500ms/step - AUC: 0.5368 - accuracy: 0.7637 - loss: 0.5508 - val_AUC: 0.4693 - val_accuracy: 0.7976 - val_loss: 0.5456
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 14s 449ms/step - AUC: 0.4633 - accuracy: 0.7797 - loss: 0.5490 - val_AUC: 0.5544 - val_accuracy: 0.7976 - val_loss: 0.5245
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 768ms/step - AUC: 0.4577 - accuracy: 0.7804 - loss: 0.5433 - val_AUC: 0.5966 - val_accuracy: 0.7976 - val_loss: 0.5046
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 810ms/step - AUC: 0.5107 - accuracy: 0.7970 - loss: 0.5219 - val_AUC: 0.5764 - val_accuracy: 0.7976 - val_loss: 0.5075
# Epoch 6/50
#  2/17 ━━━━━━━━━━━━━━━━━━━━ 1:24 6s/step - AUC: 0.6079 - accuracy: 0.8625 - loss: 0.4540
