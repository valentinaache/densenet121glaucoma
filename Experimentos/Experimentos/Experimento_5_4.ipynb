# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    brightness_range=[0.8, 1.2],
    validation_split=0.2
)


test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.keras"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.9036
# Epoch 1: val_loss improved from inf to 1.20322, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 70s 5s/step - loss: 0.8970 - val_loss: 1.2032
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.4020
# Epoch 2: val_loss did not improve from 1.20322
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - loss: 0.4031 - val_loss: 2.3366
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.3820
# Epoch 3: val_loss improved from 1.20322 to 1.07477, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 363ms/step - loss: 0.3788 - val_loss: 1.0748
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2884
# Epoch 4: val_loss did not improve from 1.07477
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - loss: 0.2932 - val_loss: 1.1445
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.3041
# Epoch 5: val_loss did not improve from 1.07477
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.3055 - val_loss: 2.2305
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.3141
# Epoch 6: val_loss improved from 1.07477 to 0.96486, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 414ms/step - loss: 0.3125 - val_loss: 0.9649
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.1978
# Epoch 7: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.2033 - val_loss: 1.3255
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.2119
# Epoch 8: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 263ms/step - loss: 0.2121 - val_loss: 1.7749
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.1855
# Epoch 9: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 485ms/step - loss: 0.1870 - val_loss: 1.1604
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.1915
# Epoch 10: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.1913 - val_loss: 1.9043
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.1271
# Epoch 11: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 362ms/step - loss: 0.1295 - val_loss: 1.4094
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0
50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0276
# Epoch 36: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - loss: 0.0274 - val_loss: 2.3509
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0376
# Epoch 37: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.0368 - val_loss: 3.0173
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0262
# Epoch 38: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 343ms/step - loss: 0.0262 - val_loss: 2.9684
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0224
# Epoch 39: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 288ms/step - loss: 0.0222 - val_loss: 2.8139
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0196
# Epoch 40: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 14s 317ms/step - loss: 0.0194 - val_loss: 3.0303
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0144
# Epoch 41: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 306ms/step - loss: 0.0145 - val_loss: 2.9318
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0106
# Epoch 42: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step - loss: 0.0109 - val_loss: 3.0493
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0147
# Epoch 43: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 257ms/step - loss: 0.0146 - val_loss: 3.2830
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0124
# Epoch 44: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 483ms/step - loss: 0.0127 - val_loss: 2.7769
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0096
# Epoch 45: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 289ms/step - loss: 0.0100 - val_loss: 3.6954
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0131
# Epoch 46: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - loss: 0.0129 - val_loss: 3.2281
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0119
# Epoch 47: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 321ms/step - loss: 0.0119 - val_loss: 3.7372
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0157
# Epoch 48: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - loss: 0.0155 - val_loss: 3.3037
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0108
# Epoch 49: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 277ms/step - loss: 0.0108 - val_loss: 2.8228
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.0160
# Epoch 50: val_loss did not improve from 0.96486
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 17s 987ms/step - loss: 0.0158 - val_loss: 3.7152

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.keras")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.000001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.keras"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - loss: 0.6164
# Epoch 1: val_loss improved from inf to 0.92494, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 272s 14s/step - loss: 0.6189 - val_loss: 0.9249
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 0.6102
# Epoch 2: val_loss improved from 0.92494 to 0.90821, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 731ms/step - loss: 0.6109 - val_loss: 0.9082
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.2637
# Epoch 66: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 468ms/step - loss: 0.2636 - val_loss: 0.9926
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.2644
# Epoch 67: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - loss: 0.2645 - val_loss: 1.1025
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - loss: 0.2767
# Epoch 68: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 429ms/step - loss: 0.2749 - val_loss: 1.1012
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - loss: 0.2677
# Epoch 69: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 433ms/step - loss: 0.2679 - val_loss: 1.1171
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - loss: 0.2232
# Epoch 70: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 631ms/step - loss: 0.2244 - val_loss: 1.0996
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 0.2609
# Epoch 71: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 429ms/step - loss: 0.2595 - val_loss: 1.0764
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - loss: 0.3141
# Epoch 72: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 460ms/step - loss: 0.3085 - val_loss: 0.9954
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 0.2373
# Epoch 73: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 452ms/step - loss: 0.2380 - val_loss: 1.1112
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 0.2915
# Epoch 74: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 0.2884 - val_loss: 1.1666
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.2413
# Epoch 75: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 412ms/step - loss: 0.2413 - val_loss: 1.0857
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - loss: 0.2319
# Epoch 76: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 459ms/step - loss: 0.2330 - val_loss: 1.0559
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 0.2540
# Epoch 77: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 429ms/step - loss: 0.2536 - val_loss: 1.1645
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 0.2734
# Epoch 78: val_loss did not improve from 0.66238
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 460ms/step - loss: 0.2727 - val_loss: 1.1352

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator, verbose=1)
y_test = test_generator.classes


thresholds = np.arange(0.1, 1.0, 0.1)
best_threshold = 0.5
best_f1 = 0

for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    f1 = f1_score(y_test, predicted_classes_test)
    precision = precision_score(y_test, predicted_classes_test)
    recall = recall_score(y_test, predicted_classes_test)

    print(f'Threshold: {threshold:.2f}')
    print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}\n')


    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f'Mejor threshold: {best_threshold} con F1 Score: {best_f1}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step
# Threshold: 0.10
# Precision: 0.2125, Recall: 1.0000, F1 Score: 0.3505
#
# Threshold: 0.20
# Precision: 0.2055, Recall: 0.8824, F1 Score: 0.3333
#
# Threshold: 0.30
# Precision: 0.2031, Recall: 0.7647, F1 Score: 0.3210
#
# Threshold: 0.40
# Precision: 0.2273, Recall: 0.5882, F1 Score: 0.3279
#
# Threshold: 0.50
# Precision: 0.2143, Recall: 0.3529, F1 Score: 0.2667
#
# Threshold: 0.60
# Precision: 0.1875, Recall: 0.1765, F1 Score: 0.1818
#
# Threshold: 0.70
# Precision: 0.3000, Recall: 0.1765, F1 Score: 0.2222
#
# Threshold: 0.80
# Precision: 0.3333, Recall: 0.0588, F1 Score: 0.1000
#
# Threshold: 0.90
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Mejor threshold: 0.1 con F1 Score: 0.35051546391752575
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# Inicializar listas para almacenar las métricas
precisions = []
recalls = []
f1_scores = []

# Iterar sobre diferentes thresholds y calcular las métricas
for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    precisions.append(precision_score(y_test, predicted_classes_test))
    recalls.append(recall_score(y_test, predicted_classes_test))
    f1_scores.append(f1_score(y_test, predicted_classes_test))

# Graficar las métricas en función de los thresholds
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions, label='Precision')
plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, f1_scores, label='F1 Score')
plt.xlabel('Threshold')
plt.ylabel('Metric Value')
plt.title('Metrics vs. Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Evaluar con el mejor threshold encontrado
predicted_classes_test = (predictions_test >= best_threshold).astype(int)
print("Test set classification report with custom threshold:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))

precision = precision_score(y_test, predicted_classes_test)
recall = recall_score(y_test, predicted_classes_test)

print("Precision (Test Set, Class 1) with custom threshold:", precision)
print("Recall (Test Set, Class 1) with custom threshold:", recall)

auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score:", auc_score_test)
# Out:
# Test set classification report with custom threshold:
#               precision    recall  f1-score   support
#
#      Clase 0       1.00      0.06      0.11        67
#      Clase 1       0.21      1.00      0.35        17
#
#     accuracy                           0.25        84
#    macro avg       0.61      0.53      0.23        84
# weighted avg       0.84      0.25      0.16        84
#
# Precision (Test Set, Class 1) with custom threshold: 0.2125
# Recall (Test Set, Class 1) with custom threshold: 1.0
# Test set AUC Score: 0.5118525021949079

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, predictions_test)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# #RESULTADOS ANTERIORES

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 7s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.79      0.93      0.86        67
#      Clase 1       0.17      0.06      0.09        17
#
#     accuracy                           0.75        84
#    macro avg       0.48      0.49      0.47        84
# weighted avg       0.67      0.75      0.70        84
#
# Test set AUC Score after warmup: 0.6233538191395961
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.88      0.99      0.93       265
#      Clase 1       0.94      0.49      0.64        70
#
#     accuracy                           0.89       335
#    macro avg       0.91      0.74      0.79       335
# weighted avg       0.89      0.89      0.87       335
#
# Train set AUC Score after warmup: 0.8120754716981131

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.78      0.58      0.67        67
#      Clase 1       0.18      0.35      0.24        17
#
#     accuracy                           0.54        84
#    macro avg       0.48      0.47      0.45        84
# weighted avg       0.66      0.54      0.58        84
#
# Test set AUC Score after fine-tuning: 0.4995610184372256
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 561ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.87      0.73      0.80       265
#      Clase 1       0.37      0.60      0.46        70
#
#     accuracy                           0.70       335
#    macro avg       0.62      0.67      0.63       335
# weighted avg       0.77      0.70      0.73       335
#
# Train set AUC Score after fine-tuning: 0.7300269541778976

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')

# %%
from sklearn.metrics import precision_score, recall_score

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)
y_test = test_generator.classes

precision = precision_score(y_test, predicted_classes_test, average='binary', pos_label=1)
recall = recall_score(y_test, predicted_classes_test, average='binary', pos_label=1)

print("Precision (Test Set, Class 1):", precision)
print("Recall (Test Set, Class 1):", recall)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Precision (Test Set, Class 1): 0.17647058823529413
# Recall (Test Set, Class 1): 0.35294117647058826
