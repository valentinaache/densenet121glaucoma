# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    zoom_range=0.1,
    brightness_range=[0.8, 1.2],
    validation_split=0.2
)


test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.h5"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - ETA: 0s - loss: 0.6875
# Epoch 1: val_loss improved from inf to 0.79292, saving model to best_model_warmup.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 25s 1s/step - loss: 0.6875 - val_loss: 0.7929
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3474
# Epoch 2: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 729ms/step - loss: 0.3474 - val_loss: 1.0575
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2677
# Epoch 3: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 859ms/step - loss: 0.2677 - val_loss: 2.0387
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2759
# Epoch 4: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 593ms/step - loss: 0.2759 - val_loss: 1.2226
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2331
# Epoch 5: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 622ms/step - loss: 0.2331 - val_loss: 0.9427
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2208
# Epoch 6: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 785ms/step - loss: 0.2208 - val_loss: 1.6634
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1855
# Epoch 7: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 609ms/step - loss: 0.1855 - val_loss: 1.4918
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2104
# Epoch 8: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 807ms/step - loss: 0.2104 - val_loss: 1.8417
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1968
# Epoch 9: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 662ms/step - loss: 0.1968 - val_loss: 1.9751
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1854
# Epoch 10: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 795ms/step - loss: 0.1854 - val_loss: 2.4694
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1556
# Epoch 11: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 626ms/step - loss: 0.1556 - val_loss: 2.3211
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1746
# Epoch 12: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 783ms/step - loss: 0.1746 - val_loss: 1.0760
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1122
# Epoch 13: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 612ms/step - loss: 0.1122 - val_loss: 2.5286
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0999
# Epoch 14: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 808ms/step - loss: 0.0999 - val_loss: 1.6955
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0952
# Epoch 15: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 624ms/step - loss: 0.0952 - val_loss: 1.6613
# Epoch 16/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0921
# Epoch 16: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 797ms/step - loss: 0.0921 - val_loss: 2.1447
# Epoch 17/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0839
# Epoch 17: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 613ms/step - loss: 0.0839 - val_loss: 1.5413
# Epoch 18/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1179
# Epoch 18: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 698ms/step - loss: 0.1179 - val_loss: 2.5519
# Epoch 19/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 19: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 654ms/step - loss: 0.0779 - val_loss: 2.5959
# Epoch 20/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0690
# Epoch 20: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 799ms/step - loss: 0.0690 - val_loss: 1.8358
# Epoch 21/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0746
# Epoch 21: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 605ms/step - loss: 0.0746 - val_loss: 2.3266
# Epoch 22/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0755
# Epoch 22: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 852ms/step - loss: 0.0755 - val_loss: 2.4189
# Epoch 23/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0461
# Epoch 23: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 601ms/step - loss: 0.0461 - val_loss: 2.4073
# Epoch 24/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0492
# Epoch 24: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 607ms/step - loss: 0.0492 - val_loss: 2.6453
# Epoch 25/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0548
# Epoch 25: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 603ms/step - loss: 0.0548 - val_loss: 3.1208
# Epoch 26/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0530
# Epoch 26: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 796ms/step - loss: 0.0530 - val_loss: 2.0827
# Epoch 27/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 27: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 620ms/step - loss: 0.0462 - val_loss: 2.4054
# Epoch 28/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0322
# Epoch 28: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 793ms/step - loss: 0.0322 - val_loss: 3.0194
# Epoch 29/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 29: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 603ms/step - loss: 0.0491 - val_loss: 3.1902
# Epoch 30/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0429
# Epoch 30: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 764ms/step - loss: 0.0429 - val_loss: 2.1470
# Epoch 31/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0537
# Epoch 31: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 621ms/step - loss: 0.0537 - val_loss: 1.9573
# Epoch 32/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0254
# Epoch 32: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 600ms/step - loss: 0.0254 - val_loss: 3.4058
# Epoch 33/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 33: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 830ms/step - loss: 0.0270 - val_loss: 2.6440
# Epoch 34/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 34: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 600ms/step - loss: 0.0218 - val_loss: 3.0193
# Epoch 35/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 35: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 801ms/step - loss: 0.0247 - val_loss: 2.4362
# Epoch 36/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0284
# Epoch 36: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 603ms/step - loss: 0.0284 - val_loss: 3.5932
# Epoch 37/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 37: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 787ms/step - loss: 0.0173 - val_loss: 3.3182
# Epoch 38/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0191
# Epoch 38: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 598ms/step - loss: 0.0191 - val_loss: 2.9233
# Epoch 39/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 39: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 766ms/step - loss: 0.0185 - val_loss: 3.3538
# Epoch 40/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0190
# Epoch 40: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 606ms/step - loss: 0.0190 - val_loss: 2.6160
# Epoch 41/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 41: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 800ms/step - loss: 0.0131 - val_loss: 3.2148
# Epoch 42/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 42: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 606ms/step - loss: 0.0104 - val_loss: 3.5362
# Epoch 43/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 43: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 847ms/step - loss: 0.0146 - val_loss: 2.7881
# Epoch 44/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 44: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 603ms/step - loss: 0.0124 - val_loss: 2.9550
# Epoch 45/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 45: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 790ms/step - loss: 0.0169 - val_loss: 3.6493
# Epoch 46/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 46: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 600ms/step - loss: 0.0121 - val_loss: 2.9214
# Epoch 47/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0188
# Epoch 47: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 803ms/step - loss: 0.0188 - val_loss: 3.0721
# Epoch 48/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 48: val_loss did not improve from 0.79292
# 9/9 [==============================] - 5s 612ms/step - loss: 0.0124 - val_loss: 4.1937
# Epoch 49/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0119
# Epoch 49: val_loss did not improve from 0.79292
# 9/9 [==============================] - 6s 664ms/step - loss: 0.0119 - val_loss: 2.8677
# Epoch 50/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 50: val_loss did not improve from 0.79292
# 9/9 [==============================] - 7s 750ms/step - loss: 0.0136 - val_loss: 4.0370

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 [==============================] - 6s 2s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      0.99      0.89        67
#      Clase 1       0.50      0.06      0.11        17
#
#     accuracy                           0.80        84
#    macro avg       0.65      0.52      0.50        84
# weighted avg       0.74      0.80      0.73        84
#
# Test set AUC Score after warmup: 0.6189640035118524
# 11/11 [==============================] - 5s 500ms/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.87      1.00      0.93       265
#      Clase 1       0.97      0.43      0.59        70
#
#     accuracy                           0.88       335
#    macro avg       0.92      0.71      0.76       335
# weighted avg       0.89      0.88      0.86       335
#
# Train set AUC Score after warmup: 0.8155256064690026

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.h5")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.000001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.h5"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8636
# Epoch 1: val_loss improved from inf to 0.76096, saving model to best_model_finetune.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 83s 2s/step - loss: 0.8636 - val_loss: 0.7610
# Epoch 2/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8355
# Epoch 2: val_loss improved from 0.76096 to 0.71237, saving model to best_model_finetune.h5
# 9/9 [==============================] - 9s 1s/step - loss: 0.8355 - val_loss: 0.7124
# Epoch 3/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8197
# Epoch 3: val_loss did not improve from 0.71237
# 9/9 [==============================] - 7s 817ms/step - loss: 0.8197 - val_loss: 0.7162
# Epoch 4/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8134
# Epoch 4: val_loss improved from 0.71237 to 0.69126, saving model to best_model_finetune.h5
# 9/9 [==============================] - 8s 862ms/step - loss: 0.8134 - val_loss: 0.6913
# Epoch 5/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7722
# Epoch 5: val_loss improved from 0.69126 to 0.68457, saving model to best_model_finetune.h5
# 9/9 [==============================] - 9s 1s/step - loss: 0.7722 - val_loss: 0.6846
# Epoch 6/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7464
# Epoch 6: val_loss improved from 0.68457 to 0.63759, saving model to best_model_finetune.h5
# 9/9 [==============================] - 8s 896ms/step - loss: 0.7464 - val_loss: 0.6376
# Epoch 7/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7332
# Epoch 7: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 854ms/step - loss: 0.7332 - val_loss: 0.6809
# Epoch 8/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7169
# Epoch 8: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 890ms/step - loss: 0.7169 - val_loss: 0.6806
# Epoch 9/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6755
# Epoch 9: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 699ms/step - loss: 0.6755 - val_loss: 0.6558
# Epoch 10/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6726
# Epoch 10: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 833ms/step - loss: 0.6726 - val_loss: 0.6592
# Epoch 11/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6625
# Epoch 11: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 872ms/step - loss: 0.6625 - val_loss: 0.6673
# Epoch 12/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6355
# Epoch 12: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 707ms/step - loss: 0.6355 - val_loss: 0.6927
# Epoch 13/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6101
# Epoch 13: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 852ms/step - loss: 0.6101 - val_loss: 0.6504
# Epoch 14/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6094
# Epoch 14: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 683ms/step - loss: 0.6094 - val_loss: 0.6561
# Epoch 15/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5855
# Epoch 15: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 828ms/step - loss: 0.5855 - val_loss: 0.6804
# Epoch 16/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5739
# Epoch 16: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 677ms/step - loss: 0.5739 - val_loss: 0.6927
# Epoch 17/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5609
# Epoch 17: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 689ms/step - loss: 0.5609 - val_loss: 0.6845
# Epoch 18/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5547
# Epoch 18: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 844ms/step - loss: 0.5547 - val_loss: 0.6925
# Epoch 19/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5320
# Epoch 19: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 692ms/step - loss: 0.5320 - val_loss: 0.6687
# Epoch 20/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5261
# Epoch 20: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 683ms/step - loss: 0.5261 - val_loss: 0.6502
# Epoch 21/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5251
# Epoch 21: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 862ms/step - loss: 0.5251 - val_loss: 0.6984
# Epoch 22/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5173
# Epoch 22: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 754ms/step - loss: 0.5173 - val_loss: 0.6589
# Epoch 23/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4931
# Epoch 23: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 882ms/step - loss: 0.4931 - val_loss: 0.6973
# Epoch 24/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4869
# Epoch 24: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 673ms/step - loss: 0.4869 - val_loss: 0.6979
# Epoch 25/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4712
# Epoch 25: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 695ms/step - loss: 0.4712 - val_loss: 0.7207
# Epoch 26/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4721
# Epoch 26: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 725ms/step - loss: 0.4721 - val_loss: 0.6781
# Epoch 27/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4421
# Epoch 27: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 872ms/step - loss: 0.4421 - val_loss: 0.6974
# Epoch 28/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4547
# Epoch 28: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 685ms/step - loss: 0.4547 - val_loss: 0.6735
# Epoch 29/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4533
# Epoch 29: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 878ms/step - loss: 0.4533 - val_loss: 0.6969
# Epoch 30/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4517
# Epoch 30: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 866ms/step - loss: 0.4517 - val_loss: 0.7011
# Epoch 31/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4425
# Epoch 31: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 683ms/step - loss: 0.4425 - val_loss: 0.7268
# Epoch 32/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4373
# Epoch 32: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 840ms/step - loss: 0.4373 - val_loss: 0.7246
# Epoch 33/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4280
# Epoch 33: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 682ms/step - loss: 0.4280 - val_loss: 0.7164
# Epoch 34/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4085
# Epoch 34: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 877ms/step - loss: 0.4085 - val_loss: 0.7406
# Epoch 35/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4070
# Epoch 35: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 751ms/step - loss: 0.4070 - val_loss: 0.7148
# Epoch 36/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4091
# Epoch 36: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 870ms/step - loss: 0.4091 - val_loss: 0.7548
# Epoch 37/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4166
# Epoch 37: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 739ms/step - loss: 0.4166 - val_loss: 0.7308
# Epoch 38/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3841
# Epoch 38: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 681ms/step - loss: 0.3841 - val_loss: 0.7121
# Epoch 39/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3968
# Epoch 39: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 871ms/step - loss: 0.3968 - val_loss: 0.7056
# Epoch 40/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4089
# Epoch 40: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 700ms/step - loss: 0.4089 - val_loss: 0.7411
# Epoch 41/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3905
# Epoch 41: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 688ms/step - loss: 0.3905 - val_loss: 0.7689
# Epoch 42/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3704
# Epoch 42: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 788ms/step - loss: 0.3704 - val_loss: 0.7594
# Epoch 43/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3914
# Epoch 43: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 863ms/step - loss: 0.3914 - val_loss: 0.7591
# Epoch 44/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3696
# Epoch 44: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 754ms/step - loss: 0.3696 - val_loss: 0.7667
# Epoch 45/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3769
# Epoch 45: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 697ms/step - loss: 0.3769 - val_loss: 0.7698
# Epoch 46/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3609
# Epoch 46: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 829ms/step - loss: 0.3609 - val_loss: 0.7832
# Epoch 47/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3640
# Epoch 47: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 661ms/step - loss: 0.3640 - val_loss: 0.7882
# Epoch 48/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3517
# Epoch 48: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 808ms/step - loss: 0.3517 - val_loss: 0.8287
# Epoch 49/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3422
# Epoch 49: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 660ms/step - loss: 0.3422 - val_loss: 0.8176
# Epoch 50/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3537
# Epoch 50: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 829ms/step - loss: 0.3537 - val_loss: 0.7567
# Epoch 51/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3390
# Epoch 51: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 856ms/step - loss: 0.3390 - val_loss: 0.7793
# Epoch 52/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3473
# Epoch 52: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 672ms/step - loss: 0.3473 - val_loss: 0.8635
# Epoch 53/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3335
# Epoch 53: val_loss did not improve from 0.63759
# 9/9 [==============================] - 7s 799ms/step - loss: 0.3335 - val_loss: 0.8481
# Epoch 54/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3422
# Epoch 54: val_loss did not improve from 0.63759
# 9/9 [==============================] - 6s 662ms/step - loss: 0.3422 - val_loss: 0.8764
# Epoch 55/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3302
# Epoch 55: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 812ms/step - loss: 0.3302 - val_loss: 0.8464
# Epoch 56/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3443
# Epoch 56: val_loss did not improve from 0.63759
# 9/9 [==============================] - 8s 918ms/step - loss: 0.3443 - val_loss: 0.8301

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 [==============================] - 2s 141ms/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.90      0.39      0.54        67
#      Clase 1       0.25      0.82      0.39        17
#
#     accuracy                           0.48        84
#    macro avg       0.58      0.61      0.47        84
# weighted avg       0.77      0.48      0.51        84
#
# Test set AUC Score after fine-tuning: 0.6426690079016681
# 11/11 [==============================] - 2s 146ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.91      0.51      0.65       265
#      Clase 1       0.30      0.80      0.44        70
#
#     accuracy                           0.57       335
#    macro avg       0.60      0.65      0.54       335
# weighted avg       0.78      0.57      0.60       335
#
# Train set AUC Score after fine-tuning: 0.7397304582210242

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')
