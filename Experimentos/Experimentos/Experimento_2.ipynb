# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    validation_split = 0.2
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.keras"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.4617
# Epoch 1: val_loss improved from inf to 0.99462, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 62s 4s/step - loss: 0.4698 - val_loss: 0.9946
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.3799
# Epoch 2: val_loss improved from 0.99462 to 0.83787, saving model to best_model_warmup.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 351ms/step - loss: 0.3856 - val_loss: 0.8379
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.3775
# Epoch 3: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 243ms/step - loss: 0.3833 - val_loss: 1.3327
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.3709
# Epoch 4: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.3716 - val_loss: 1.0118
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.3972
# Epoch 5: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 441ms/step - loss: 0.3953 - val_loss: 0.9874
# Epoch 6/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.3797
# Epoch 6: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.3719 - val_loss: 1.3696
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.3710
# Epoch 7: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.3684 - val_loss: 1.0762
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.3064
# Epoch 8: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - loss: 0.3092 - val_loss: 1.2977
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.3128
# Epoch 9: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - loss: 0.3136 - val_loss: 1.2308
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.3643
# Epoch 10: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.3594 - val_loss: 1.3149
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.3559
# Epoch 11: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 322ms/step - loss: 0.3517 - val_loss: 1.3180
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3337
# Epoch 12: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - loss: 0.3334 - val_loss: 1.1184
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.3226
# Epoch 13: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - loss: 0.3219 - val_loss: 1.2259
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.2695
# Epoch 14: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - loss: 0.2708 - val_loss: 1.3948
# Epoch 15/50
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.3356
# Epoch 15: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - loss: 0.1964 - val_loss: 1.5139
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.2094
# Epoch 41: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - loss: 0.2133 - val_loss: 1.3400
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.2155
# Epoch 42: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 420ms/step - loss: 0.2159 - val_loss: 1.5927
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.1992
# Epoch 43: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 236ms/step - loss: 0.1985 - val_loss: 1.4589
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.2881
# Epoch 44: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - loss: 0.2798 - val_loss: 1.6264
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.2117
# Epoch 45: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - loss: 0.2112 - val_loss: 1.4981
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.1661
# Epoch 46: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - loss: 0.1678 - val_loss: 1.4127
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.2012
# Epoch 47: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 295ms/step - loss: 0.2004 - val_loss: 1.4377
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.2004
# Epoch 48: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - loss: 0.2014 - val_loss: 1.3707
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.1666
# Epoch 49: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 472ms/step - loss: 0.1663 - val_loss: 1.7024
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1697
# Epoch 50: val_loss did not improve from 0.83787
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 235ms/step - loss: 0.1711 - val_loss: 1.4322

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.keras")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.keras"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.4976
# Epoch 1: val_loss improved from inf to 2.76197, saving model to best_model_finetune.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 272s 14s/step - loss: 0.4933 - val_loss: 2.7620
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.2998
# Epoch 2: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 405ms/step - loss: 0.3049 - val_loss: 3.7947
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 0.2786
# Epoch 3: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 394ms/step - loss: 0.2802 - val_loss: 4.5216
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - loss: 0.2328
# Epoch 4: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - loss: 0.2292 - val_loss: 5.0745
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.1924
# Epoch 5: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 431ms/step - loss: 0.1885 - val_loss: 5.3261
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - loss: 0.1731
# Epoch 6: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 392ms/step - loss: 0.1706 - val_loss: 5.2969
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - loss: 0.0780
# Epoch 7: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 439ms/step - loss: 0.0833 - val_loss: 5.5621
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 0.0876
# Epoch 8: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 395ms/step - loss: 0.0900 - val_loss: 5.3105
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - loss: 0.0727
# Epoch 9: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - loss: 0.0757 - val_loss: 5.3640
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0022
# Epoch 33: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 401ms/step - loss: 0.0022 - val_loss: 5.9995
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.0370
# Epoch 34: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 466ms/step - loss: 0.0361 - val_loss: 6.9372
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0160
# Epoch 35: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 441ms/step - loss: 0.0170 - val_loss: 7.0520
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.0034
# Epoch 36: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 684ms/step - loss: 0.0034 - val_loss: 6.7990
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0053
# Epoch 37: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 17s 397ms/step - loss: 0.0066 - val_loss: 7.1005
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.0270
# Epoch 38: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 392ms/step - loss: 0.0276 - val_loss: 6.9194
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0191
# Epoch 39: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 398ms/step - loss: 0.0203 - val_loss: 6.0422
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - loss: 0.0227
# Epoch 40: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 438ms/step - loss: 0.0222 - val_loss: 6.3119
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.0391
# Epoch 41: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 410ms/step - loss: 0.0390 - val_loss: 6.0494
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.0684
# Epoch 42: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 404ms/step - loss: 0.0663 - val_loss: 6.2683
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0185
# Epoch 43: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 400ms/step - loss: 0.0273 - val_loss: 6.0298
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.0638
# Epoch 44: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 467ms/step - loss: 0.0644 - val_loss: 4.7554
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - loss: 0.0819
# Epoch 45: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 439ms/step - loss: 0.0820 - val_loss: 6.2830
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.0606
# Epoch 46: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 470ms/step - loss: 0.0598 - val_loss: 6.8960
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0117
# Epoch 47: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 400ms/step - loss: 0.0119 - val_loss: 7.1409
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.0274
# Epoch 48: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 400ms/step - loss: 0.0277 - val_loss: 6.0307
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 0.0166
# Epoch 49: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 484ms/step - loss: 0.0163 - val_loss: 5.6351
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - loss: 0.0046
# Epoch 50: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - loss: 0.0050 - val_loss: 5.6156
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - loss: 0.0020
# Epoch 51: val_loss did not improve from 2.76197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 490ms/step - loss: 0.0022 - val_loss: 5.7499

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator, verbose=1)
y_test = test_generator.classes


thresholds = np.arange(0.1, 1.0, 0.1)
best_threshold = 0.5
best_f1 = 0

for threshold in thresholds:
    predicted_classes_test = (predictions_test >= threshold).astype(int)
    f1 = f1_score(y_test, predicted_classes_test)
    precision = precision_score(y_test, predicted_classes_test)
    recall = recall_score(y_test, predicted_classes_test)

    print(f'Threshold: {threshold:.2f}')
    print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}\n')


    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f'Mejor threshold: {best_threshold} con F1 Score: {best_f1}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step
# Threshold: 0.10
# Precision: 0.2500, Recall: 0.1176, F1 Score: 0.1600
#
# Threshold: 0.20
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.30
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.40
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.50
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.60
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.70
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.80
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Threshold: 0.90
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#
# Mejor threshold: 0.1 con F1 Score: 0.16
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions, label='Precision')
plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, f1_scores, label='F1 Score')
plt.xlabel('Threshold')
plt.ylabel('Metric Value')
plt.title('Metrics vs. Threshold')
plt.legend()
plt.grid(True)
plt.show()

# Evaluar con el mejor threshold encontrado
predicted_classes_test = (predictions_test >= best_threshold).astype(int)
print("Test set classification report with custom threshold:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))

precision = precision_score(y_test, predicted_classes_test)
recall = recall_score(y_test, predicted_classes_test)

print("Precision (Test Set, Class 1) with custom threshold:", precision)
print("Recall (Test Set, Class 1) with custom threshold:", recall)

auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score:", auc_score_test)
# Out:
# Test set classification report with custom threshold:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      0.91      0.85        67
#      Clase 1       0.25      0.12      0.16        17
#
#     accuracy                           0.75        84
#    macro avg       0.53      0.51      0.51        84
# weighted avg       0.69      0.75      0.71        84
#
# Precision (Test Set, Class 1) with custom threshold: 0.25
# Recall (Test Set, Class 1) with custom threshold: 0.11764705882352941
# Test set AUC Score: 0.5557506584723442

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, predictions_test)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# #RESULTADOS ANTERIORES

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 24s 7s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.81      0.87      0.83        67
#      Clase 1       0.25      0.18      0.21        17
#
#     accuracy                           0.73        84
#    macro avg       0.53      0.52      0.52        84
# weighted avg       0.69      0.73      0.71        84
#
# Test set AUC Score after warmup: 0.5864793678665496
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.87      0.93      0.90       265
#      Clase 1       0.65      0.49      0.56        70
#
#     accuracy                           0.84       335
#    macro avg       0.76      0.71      0.73       335
# weighted avg       0.83      0.84      0.83       335
#
# Train set AUC Score after warmup: 0.7848517520215634

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)
#predicted_proba_test = predictions_test.flatten()

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

#train_generator.reset()
predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)
#predicted_proba_train = predictions_train.flatten()

y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.80      1.00      0.89        67
#      Clase 1       0.00      0.00      0.00        17
#
#     accuracy                           0.80        84
#    macro avg       0.40      0.50      0.44        84
# weighted avg       0.64      0.80      0.71        84
#
# Test set AUC Score after fine-tuning: 0.4574187884108867
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 512ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.79      1.00      0.88       265
#      Clase 1       1.00      0.01      0.03        70
#
#     accuracy                           0.79       335
#    macro avg       0.90      0.51      0.46       335
# weighted avg       0.84      0.79      0.71       335
#
# Train set AUC Score after fine-tuning: 0.6764959568733153

# %%
from sklearn.metrics import precision_score, recall_score

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)
y_test = test_generator.classes

precision = precision_score(y_test, predicted_classes_test, average='binary', pos_label=1)
recall = recall_score(y_test, predicted_classes_test, average='binary', pos_label=1)

print("Precision (Test Set, Class 1):", precision)
print("Recall (Test Set, Class 1):", recall)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Precision (Test Set, Class 1): 0.0
# Recall (Test Set, Class 1): 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')
