# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    validation_split=0.2
)


test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.h5"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - ETA: 0s - loss: 0.8077
# Epoch 1: val_loss improved from inf to 2.43589, saving model to best_model_warmup.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 26s 1s/step - loss: 0.8077 - val_loss: 2.4359
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 0.4062
# Epoch 2: val_loss improved from 2.43589 to 0.90743, saving model to best_model_warmup.h5
# 9/9 [==============================] - 7s 863ms/step - loss: 0.4062 - val_loss: 0.9074
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3591
# Epoch 3: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 557ms/step - loss: 0.3591 - val_loss: 1.3776
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3417
# Epoch 4: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 546ms/step - loss: 0.3417 - val_loss: 1.5108
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2777
# Epoch 5: val_loss did not improve from 0.90743
# 9/9 [==============================] - 7s 737ms/step - loss: 0.2777 - val_loss: 1.3518
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2616
# Epoch 6: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 542ms/step - loss: 0.2616 - val_loss: 1.4296
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2522
# Epoch 7: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 683ms/step - loss: 0.2522 - val_loss: 2.7262
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3427
# Epoch 8: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 738ms/step - loss: 0.3427 - val_loss: 1.5241
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2385
# Epoch 9: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 537ms/step - loss: 0.2385 - val_loss: 1.3948
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2070
# Epoch 10: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 710ms/step - loss: 0.2070 - val_loss: 1.4976
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2211
# Epoch 11: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 546ms/step - loss: 0.2211 - val_loss: 1.5585
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2035
# Epoch 12: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 579ms/step - loss: 0.2035 - val_loss: 1.7328
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1761
# Epoch 13: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 641ms/step - loss: 0.1761 - val_loss: 1.2801
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1665
# Epoch 14: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 534ms/step - loss: 0.1665 - val_loss: 2.0955
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1579
# Epoch 15: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 695ms/step - loss: 0.1579 - val_loss: 1.4737
# Epoch 16/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1611
# Epoch 16: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 544ms/step - loss: 0.1611 - val_loss: 2.0190
# Epoch 17/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2038
# Epoch 17: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 708ms/step - loss: 0.2038 - val_loss: 0.9690
# Epoch 18/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2195
# Epoch 18: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 537ms/step - loss: 0.2195 - val_loss: 1.0570
# Epoch 19/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1923
# Epoch 19: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 773ms/step - loss: 0.1923 - val_loss: 2.2252
# Epoch 20/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1679
# Epoch 20: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 535ms/step - loss: 0.1679 - val_loss: 2.5024
# Epoch 21/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1589
# Epoch 21: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 712ms/step - loss: 0.1589 - val_loss: 2.4192
# Epoch 22/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1746
# Epoch 22: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 530ms/step - loss: 0.1746 - val_loss: 1.5371
# Epoch 23/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1167
# Epoch 23: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 727ms/step - loss: 0.1167 - val_loss: 1.8394
# Epoch 24/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1619
# Epoch 24: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 530ms/step - loss: 0.1619 - val_loss: 1.2496
# Epoch 25/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1797
# Epoch 25: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 537ms/step - loss: 0.1797 - val_loss: 1.7714
# Epoch 26/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1255
# Epoch 26: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 703ms/step - loss: 0.1255 - val_loss: 2.6221
# Epoch 27/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1256
# Epoch 27: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 532ms/step - loss: 0.1256 - val_loss: 2.6362
# Epoch 28/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1173
# Epoch 28: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 620ms/step - loss: 0.1173 - val_loss: 1.1880
# Epoch 29/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1483
# Epoch 29: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 529ms/step - loss: 0.1483 - val_loss: 2.7937
# Epoch 30/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0952
# Epoch 30: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 717ms/step - loss: 0.0952 - val_loss: 2.7498
# Epoch 31/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1100
# Epoch 31: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 524ms/step - loss: 0.1100 - val_loss: 1.8918
# Epoch 32/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0600
# Epoch 32: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 558ms/step - loss: 0.0600 - val_loss: 2.5482
# Epoch 33/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0904
# Epoch 33: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 648ms/step - loss: 0.0904 - val_loss: 2.3658
# Epoch 34/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 34: val_loss did not improve from 0.90743
# 9/9 [==============================] - 7s 841ms/step - loss: 0.0777 - val_loss: 3.3849
# Epoch 35/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1105
# Epoch 35: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 534ms/step - loss: 0.1105 - val_loss: 2.3099
# Epoch 36/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1097
# Epoch 36: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 712ms/step - loss: 0.1097 - val_loss: 1.4837
# Epoch 37/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1035
# Epoch 37: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 534ms/step - loss: 0.1035 - val_loss: 1.5300
# Epoch 38/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0970
# Epoch 38: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 585ms/step - loss: 0.0970 - val_loss: 2.2877
# Epoch 39/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0473
# Epoch 39: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 593ms/step - loss: 0.0473 - val_loss: 3.1977
# Epoch 40/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0683
# Epoch 40: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 706ms/step - loss: 0.0683 - val_loss: 2.2198
# Epoch 41/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0712
# Epoch 41: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 529ms/step - loss: 0.0712 - val_loss: 3.3970
# Epoch 42/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0682
# Epoch 42: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 519ms/step - loss: 0.0682 - val_loss: 3.3786
# Epoch 43/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0555
# Epoch 43: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 648ms/step - loss: 0.0555 - val_loss: 2.1534
# Epoch 44/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0597
# Epoch 44: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 538ms/step - loss: 0.0597 - val_loss: 1.7066
# Epoch 45/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0877
# Epoch 45: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 659ms/step - loss: 0.0877 - val_loss: 3.1911
# Epoch 46/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0415
# Epoch 46: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 525ms/step - loss: 0.0415 - val_loss: 2.6066
# Epoch 47/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0519
# Epoch 47: val_loss did not improve from 0.90743
# 9/9 [==============================] - 6s 707ms/step - loss: 0.0519 - val_loss: 2.7740
# Epoch 48/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0814
# Epoch 48: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 525ms/step - loss: 0.0814 - val_loss: 3.9862
# Epoch 49/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0628
# Epoch 49: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 577ms/step - loss: 0.0628 - val_loss: 3.5171
# Epoch 50/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0578
# Epoch 50: val_loss did not improve from 0.90743
# 9/9 [==============================] - 5s 526ms/step - loss: 0.0578 - val_loss: 1.6684

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 [==============================] - 6s 2s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.81      0.84      0.82        67
#      Clase 1       0.27      0.24      0.25        17
#
#     accuracy                           0.71        84
#    macro avg       0.54      0.54      0.54        84
# weighted avg       0.70      0.71      0.71        84
#
# Test set AUC Score after warmup: 0.5750658472344162
# 11/11 [==============================] - 4s 421ms/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.90      0.98      0.94       265
#      Clase 1       0.87      0.59      0.70        70
#
#     accuracy                           0.90       335
#    macro avg       0.89      0.78      0.82       335
# weighted avg       0.89      0.90      0.89       335
#
# Train set AUC Score after warmup: 0.8194609164420485

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.h5")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.000001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.h5"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5494
# Epoch 1: val_loss improved from inf to 0.86560, saving model to best_model_finetune.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 77s 1s/step - loss: 0.5494 - val_loss: 0.8656
# Epoch 2/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5775
# Epoch 2: val_loss did not improve from 0.86560
# 9/9 [==============================] - 7s 773ms/step - loss: 0.5775 - val_loss: 0.8776
# Epoch 3/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5407
# Epoch 3: val_loss improved from 0.86560 to 0.86513, saving model to best_model_finetune.h5
# 9/9 [==============================] - 8s 870ms/step - loss: 0.5407 - val_loss: 0.8651
# Epoch 4/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5468
# Epoch 4: val_loss improved from 0.86513 to 0.82996, saving model to best_model_finetune.h5
# 9/9 [==============================] - 7s 832ms/step - loss: 0.5468 - val_loss: 0.8300
# Epoch 5/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5227
# Epoch 5: val_loss did not improve from 0.82996
# 9/9 [==============================] - 8s 799ms/step - loss: 0.5227 - val_loss: 0.8546
# Epoch 6/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5209
# Epoch 6: val_loss did not improve from 0.82996
# 9/9 [==============================] - 6s 605ms/step - loss: 0.5209 - val_loss: 0.8809
# Epoch 7/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5124
# Epoch 7: val_loss improved from 0.82996 to 0.81539, saving model to best_model_finetune.h5
# 9/9 [==============================] - 7s 781ms/step - loss: 0.5124 - val_loss: 0.8154
# Epoch 8/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4908
# Epoch 8: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 783ms/step - loss: 0.4908 - val_loss: 0.8689
# Epoch 9/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4856
# Epoch 9: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 611ms/step - loss: 0.4856 - val_loss: 0.8473
# Epoch 10/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4806
# Epoch 10: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 763ms/step - loss: 0.4806 - val_loss: 0.8520
# Epoch 11/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4605
# Epoch 11: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 606ms/step - loss: 0.4605 - val_loss: 0.8157
# Epoch 12/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4627
# Epoch 12: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 603ms/step - loss: 0.4627 - val_loss: 0.8779
# Epoch 13/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4363
# Epoch 13: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 661ms/step - loss: 0.4363 - val_loss: 0.9098
# Epoch 14/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4530
# Epoch 14: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 596ms/step - loss: 0.4530 - val_loss: 0.8186
# Epoch 15/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4547
# Epoch 15: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 601ms/step - loss: 0.4547 - val_loss: 0.9027
# Epoch 16/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4548
# Epoch 16: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 735ms/step - loss: 0.4548 - val_loss: 0.9069
# Epoch 17/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4433
# Epoch 17: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 606ms/step - loss: 0.4433 - val_loss: 0.9025
# Epoch 18/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3973
# Epoch 18: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 832ms/step - loss: 0.3973 - val_loss: 0.9046
# Epoch 19/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4017
# Epoch 19: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 608ms/step - loss: 0.4017 - val_loss: 0.8602
# Epoch 20/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4194
# Epoch 20: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 684ms/step - loss: 0.4194 - val_loss: 0.9427
# Epoch 21/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3920
# Epoch 21: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 670ms/step - loss: 0.3920 - val_loss: 0.9601
# Epoch 22/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4125
# Epoch 22: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 835ms/step - loss: 0.4125 - val_loss: 0.9158
# Epoch 23/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4175
# Epoch 23: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 817ms/step - loss: 0.4175 - val_loss: 0.8992
# Epoch 24/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3903
# Epoch 24: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 608ms/step - loss: 0.3903 - val_loss: 0.9392
# Epoch 25/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3846
# Epoch 25: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 720ms/step - loss: 0.3846 - val_loss: 0.9230
# Epoch 26/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3876
# Epoch 26: val_loss did not improve from 0.81539
# 9/9 [==============================] - 8s 875ms/step - loss: 0.3876 - val_loss: 0.9671
# Epoch 27/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3800
# Epoch 27: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 656ms/step - loss: 0.3800 - val_loss: 0.8945
# Epoch 28/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3703
# Epoch 28: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 642ms/step - loss: 0.3703 - val_loss: 0.9008
# Epoch 29/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3839
# Epoch 29: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 775ms/step - loss: 0.3839 - val_loss: 0.9257
# Epoch 30/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3790
# Epoch 30: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 637ms/step - loss: 0.3790 - val_loss: 0.9541
# Epoch 31/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3633
# Epoch 31: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 716ms/step - loss: 0.3633 - val_loss: 0.9118
# Epoch 32/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3911
# Epoch 32: val_loss did not improve from 0.81539
# 9/9 [==============================] - 8s 855ms/step - loss: 0.3911 - val_loss: 0.9447
# Epoch 33/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3670
# Epoch 33: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 594ms/step - loss: 0.3670 - val_loss: 0.9114
# Epoch 34/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3864
# Epoch 34: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 680ms/step - loss: 0.3864 - val_loss: 0.8805
# Epoch 35/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3485
# Epoch 35: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 648ms/step - loss: 0.3485 - val_loss: 0.9420
# Epoch 36/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3396
# Epoch 36: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 727ms/step - loss: 0.3396 - val_loss: 0.9611
# Epoch 37/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3672
# Epoch 37: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 709ms/step - loss: 0.3672 - val_loss: 0.9278
# Epoch 38/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3489
# Epoch 38: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 797ms/step - loss: 0.3489 - val_loss: 0.9548
# Epoch 39/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3390
# Epoch 39: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 610ms/step - loss: 0.3390 - val_loss: 0.9330
# Epoch 40/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3513
# Epoch 40: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 764ms/step - loss: 0.3513 - val_loss: 1.0096
# Epoch 41/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3280
# Epoch 41: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 609ms/step - loss: 0.3280 - val_loss: 0.9423
# Epoch 42/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3330
# Epoch 42: val_loss did not improve from 0.81539
# 9/9 [==============================] - 8s 874ms/step - loss: 0.3330 - val_loss: 0.9972
# Epoch 43/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3248
# Epoch 43: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 611ms/step - loss: 0.3248 - val_loss: 0.9884
# Epoch 44/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3122
# Epoch 44: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 742ms/step - loss: 0.3122 - val_loss: 1.0134
# Epoch 45/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3215
# Epoch 45: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 612ms/step - loss: 0.3215 - val_loss: 1.0004
# Epoch 46/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3280
# Epoch 46: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 672ms/step - loss: 0.3280 - val_loss: 0.9870
# Epoch 47/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3418
# Epoch 47: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 665ms/step - loss: 0.3418 - val_loss: 1.0489
# Epoch 48/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2974
# Epoch 48: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 661ms/step - loss: 0.2974 - val_loss: 1.0156
# Epoch 49/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3196
# Epoch 49: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 771ms/step - loss: 0.3196 - val_loss: 1.0509
# Epoch 50/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3052
# Epoch 50: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 611ms/step - loss: 0.3052 - val_loss: 1.0133
# Epoch 51/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2984
# Epoch 51: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 603ms/step - loss: 0.2984 - val_loss: 1.0811
# Epoch 52/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3139
# Epoch 52: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 699ms/step - loss: 0.3139 - val_loss: 1.0630
# Epoch 53/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3379
# Epoch 53: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 609ms/step - loss: 0.3379 - val_loss: 1.0461
# Epoch 54/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3267
# Epoch 54: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 751ms/step - loss: 0.3267 - val_loss: 1.1450
# Epoch 55/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3187
# Epoch 55: val_loss did not improve from 0.81539
# 9/9 [==============================] - 7s 829ms/step - loss: 0.3187 - val_loss: 1.0733
# Epoch 56/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3211
# Epoch 56: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 606ms/step - loss: 0.3211 - val_loss: 1.1061
# Epoch 57/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3101
# Epoch 57: val_loss did not improve from 0.81539
# 9/9 [==============================] - 6s 628ms/step - loss: 0.3101 - val_loss: 1.0928

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 [==============================] - 3s 186ms/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.84      0.61      0.71        67
#      Clase 1       0.26      0.53      0.35        17
#
#     accuracy                           0.60        84
#    macro avg       0.55      0.57      0.53        84
# weighted avg       0.72      0.60      0.63        84
#
# Test set AUC Score after fine-tuning: 0.5812115891132572
# 11/11 [==============================] - 1s 133ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.87      0.69      0.77       265
#      Clase 1       0.34      0.60      0.44        70
#
#     accuracy                           0.67       335
#    macro avg       0.60      0.65      0.60       335
# weighted avg       0.76      0.67      0.70       335
#
# Train set AUC Score after fine-tuning: 0.6941239892183289

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')
