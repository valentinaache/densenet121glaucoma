# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os

# Ruta al directorio con las imágenes
directorio_imagenes = '/content/drive/My Drive/Proyecto de Grado G/ProcessedImages_Disc_Exp2'

imagenes_info = []
for filename in os.listdir(directorio_imagenes):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        base = filename.split('_')[0]
        id_paciente = base[3:-2]  # Extrae correctamente el ID del paciente
        tipo_ojo = base[-2:]
        full_path = os.path.join(directorio_imagenes, filename)
        imagenes_info.append({'filename': full_path, 'id': id_paciente, 'eye': tipo_ojo})

imagenes_df = pd.DataFrame(imagenes_info)

# Cargar y preparar los datos clínicos
data_od = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_od.xlsx')
data_os = pd.read_excel('/content/drive/My Drive/Proyecto de Grado G/patient_data_os.xlsx')

data_od['id'] = data_od['Unnamed: 0'].str.replace('#', '').astype(str)
data_os['id'] = data_os['Unnamed: 0'].str.replace('#', '').astype(str)

data_od['eye'] = 'OD'
data_os['eye'] = 'OS'

data_clinica = pd.concat([data_od[['id', 'eye', 'Diagnosis']], data_os[['id', 'eye', 'Diagnosis']]])

full_df = pd.merge(imagenes_df, data_clinica, on=['id', 'eye'], how='left')
full_df = full_df[full_df['Diagnosis'] != 2]  # Asume que quieres excluir los diagnósticos '2'

# Ahora necesitamos preparar los datos para un split estratificado
# Primero, determina la "etiqueta" dominante para cada paciente
dominant_diagnosis = full_df.groupby('id')['Diagnosis'].agg(lambda x: x.mode()[0])

# Crea el dataframe para el split estratificado
patient_df = pd.DataFrame(dominant_diagnosis).reset_index()

# Stratified split en los pacientes
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_patients, test_patients = next(splitter.split(patient_df, patient_df['Diagnosis']))

# Obtén los ID de pacientes para cada conjunto
train_ids = patient_df.iloc[train_patients]['id']
test_ids = patient_df.iloc[test_patients]['id']

# Finalmente, selecciona las filas correspondientes en full_df
train_df = full_df[full_df['id'].isin(train_ids)]
test_df = full_df[full_df['id'].isin(test_ids)]

print("Train DataFrame:")
print(train_df[['filename', 'id', 'eye', 'Diagnosis']].head())

print("\nTest DataFrame:")
print(test_df[['filename', 'id', 'eye', 'Diagnosis']].head())
# Out:
# Train DataFrame:
#                                              filename   id eye Diagnosis
# 2   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OD         1
# 3   /content/drive/My Drive/Proyecto de Grado G/Pr...  004  OS         1
# 4   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OD         1
# 5   /content/drive/My Drive/Proyecto de Grado G/Pr...  005  OS         1
# 14  /content/drive/My Drive/Proyecto de Grado G/Pr...  010  OD         1
#
# Test DataFrame:
#                                              filename   id eye Diagnosis
# 20  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OD         1
# 21  /content/drive/My Drive/Proyecto de Grado G/Pr...  015  OS         1
# 32  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OD         1
# 33  /content/drive/My Drive/Proyecto de Grado G/Pr...  023  OS         1
# 42  /content/drive/My Drive/Proyecto de Grado G/Pr...  028  OD         0

# %%
import pandas as pd
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import roc_auc_score

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calcular los pesos de clases
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['Diagnosis']),
    y=train_df['Diagnosis'].astype(int)
)
class_weights = dict(enumerate(class_weights))

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.6320754716981132, 1: 2.392857142857143}

# %%
# Configuración del modelo
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    validation_split = 0.2
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

train_b_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
# Cambiar el tipo de 'Diagnosis' a string usando .loc para evitar SettingWithCopyWarning
train_df.loc[:, 'Diagnosis'] = train_df['Diagnosis'].astype(str)
test_df.loc[:, 'Diagnosis'] = test_df['Diagnosis'].astype(str)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    subset='training'
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False,
    subset='validation'
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)

train_b_generator = train_b_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='Diagnosis',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 268 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Found 84 validated image filenames belonging to 2 classes.
# Found 335 validated image filenames belonging to 2 classes.

# %%
# Calentamiento del modelo con pesos de clase
checkpoint_path = "best_model_warmup.h5"
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", mode='min', verbose=1)

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - ETA: 0s - loss: 0.7960
# Epoch 1: val_loss improved from inf to 1.44278, saving model to best_model_warmup.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 106s 11s/step - loss: 0.7960 - val_loss: 1.4428
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 0.4149
# Epoch 2: val_loss improved from 1.44278 to 1.33493, saving model to best_model_warmup.h5
# 9/9 [==============================] - 8s 877ms/step - loss: 0.4149 - val_loss: 1.3349
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3328
# Epoch 3: val_loss improved from 1.33493 to 0.79706, saving model to best_model_warmup.h5
# 9/9 [==============================] - 7s 821ms/step - loss: 0.3328 - val_loss: 0.7971
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3311
# Epoch 4: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 813ms/step - loss: 0.3311 - val_loss: 1.9248
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3331
# Epoch 5: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 593ms/step - loss: 0.3331 - val_loss: 1.4374
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3182
# Epoch 6: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 567ms/step - loss: 0.3182 - val_loss: 0.8910
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3351
# Epoch 7: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 794ms/step - loss: 0.3351 - val_loss: 1.1672
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3000
# Epoch 8: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 562ms/step - loss: 0.3000 - val_loss: 1.6381
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2534
# Epoch 9: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 747ms/step - loss: 0.2534 - val_loss: 1.1402
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2552
# Epoch 10: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 555ms/step - loss: 0.2552 - val_loss: 1.0229
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3164
# Epoch 11: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 771ms/step - loss: 0.3164 - val_loss: 1.8012
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2943
# Epoch 12: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 553ms/step - loss: 0.2943 - val_loss: 2.4196
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3066
# Epoch 13: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 559ms/step - loss: 0.3066 - val_loss: 1.5269
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2530
# Epoch 14: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 726ms/step - loss: 0.2530 - val_loss: 1.9330
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1986
# Epoch 15: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 557ms/step - loss: 0.1986 - val_loss: 1.1543
# Epoch 16/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2308
# Epoch 16: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 713ms/step - loss: 0.2308 - val_loss: 1.9039
# Epoch 17/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2714
# Epoch 17: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 559ms/step - loss: 0.2714 - val_loss: 1.3918
# Epoch 18/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2173
# Epoch 18: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 782ms/step - loss: 0.2173 - val_loss: 1.0039
# Epoch 19/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3235
# Epoch 19: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 558ms/step - loss: 0.3235 - val_loss: 1.7959
# Epoch 20/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2269
# Epoch 20: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 670ms/step - loss: 0.2269 - val_loss: 2.3203
# Epoch 21/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2674
# Epoch 21: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 624ms/step - loss: 0.2674 - val_loss: 1.5749
# Epoch 22/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1987
# Epoch 22: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 558ms/step - loss: 0.1987 - val_loss: 1.1765
# Epoch 23/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2071
# Epoch 23: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 790ms/step - loss: 0.2071 - val_loss: 1.4909
# Epoch 24/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2108
# Epoch 24: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 573ms/step - loss: 0.2108 - val_loss: 1.6833
# Epoch 25/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2328
# Epoch 25: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 660ms/step - loss: 0.2328 - val_loss: 2.5317
# Epoch 26/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1948
# Epoch 26: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 634ms/step - loss: 0.1948 - val_loss: 1.6046
# Epoch 27/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1759
# Epoch 27: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 763ms/step - loss: 0.1759 - val_loss: 1.6768
# Epoch 28/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1462
# Epoch 28: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 612ms/step - loss: 0.1462 - val_loss: 2.3465
# Epoch 29/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1411
# Epoch 29: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 586ms/step - loss: 0.1411 - val_loss: 1.9796
# Epoch 30/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1694
# Epoch 30: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 568ms/step - loss: 0.1694 - val_loss: 1.5041
# Epoch 31/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1216
# Epoch 31: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 780ms/step - loss: 0.1216 - val_loss: 2.1662
# Epoch 32/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1280
# Epoch 32: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 635ms/step - loss: 0.1280 - val_loss: 2.2179
# Epoch 33/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1316
# Epoch 33: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 698ms/step - loss: 0.1316 - val_loss: 1.7790
# Epoch 34/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1287
# Epoch 34: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 561ms/step - loss: 0.1287 - val_loss: 2.2622
# Epoch 35/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1189
# Epoch 35: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 736ms/step - loss: 0.1189 - val_loss: 2.1375
# Epoch 36/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0975
# Epoch 36: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0975 - val_loss: 1.7316
# Epoch 37/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1309
# Epoch 37: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 723ms/step - loss: 0.1309 - val_loss: 2.5669
# Epoch 38/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2147
# Epoch 38: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 560ms/step - loss: 0.2147 - val_loss: 4.5739
# Epoch 39/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2863
# Epoch 39: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 824ms/step - loss: 0.2863 - val_loss: 2.2496
# Epoch 40/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2153
# Epoch 40: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 556ms/step - loss: 0.2153 - val_loss: 1.1265
# Epoch 41/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1858
# Epoch 41: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 782ms/step - loss: 0.1858 - val_loss: 3.1629
# Epoch 42/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2576
# Epoch 42: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 689ms/step - loss: 0.2576 - val_loss: 1.9070
# Epoch 43/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1432
# Epoch 43: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 835ms/step - loss: 0.1432 - val_loss: 1.8526
# Epoch 44/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1005
# Epoch 44: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 591ms/step - loss: 0.1005 - val_loss: 2.0009
# Epoch 45/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0892
# Epoch 45: val_loss did not improve from 0.79706
# 9/9 [==============================] - 7s 813ms/step - loss: 0.0892 - val_loss: 2.1506
# Epoch 46/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0863
# Epoch 46: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 573ms/step - loss: 0.0863 - val_loss: 2.5544
# Epoch 47/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1046
# Epoch 47: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 705ms/step - loss: 0.1046 - val_loss: 1.7125
# Epoch 48/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1287
# Epoch 48: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 562ms/step - loss: 0.1287 - val_loss: 2.4941
# Epoch 49/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0758
# Epoch 49: val_loss did not improve from 0.79706
# 9/9 [==============================] - 6s 730ms/step - loss: 0.0758 - val_loss: 2.0772
# Epoch 50/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0922
# Epoch 50: val_loss did not improve from 0.79706
# 9/9 [==============================] - 5s 562ms/step - loss: 0.0922 - val_loss: 2.0436

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after warmup:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after warmup:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)

y_train = train_b_generator.classes

print("Train set classification report after warmup:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after warmup:", auc_score_train)
# Out:
# 3/3 [==============================] - 22s 10s/step
# Test set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.83      0.90      0.86        67
#      Clase 1       0.42      0.29      0.34        17
#
#     accuracy                           0.77        84
#    macro avg       0.62      0.59      0.60        84
# weighted avg       0.75      0.77      0.76        84
#
# Test set AUC Score after warmup: 0.6215978928884986
# 11/11 [==============================] - 5s 454ms/step
# Train set classification report after warmup:
#               precision    recall  f1-score   support
#
#      Clase 0       0.88      0.97      0.92       265
#      Clase 1       0.80      0.51      0.63        70
#
#     accuracy                           0.87       335
#    macro avg       0.84      0.74      0.77       335
# weighted avg       0.87      0.87      0.86       335
#
# Train set AUC Score after warmup: 0.8073315363881403

# %%
def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()

plot_training_curves(history, 'Curvas de Calentamiento')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
model.load_weights("best_model_warmup.h5")

for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.000001), loss='binary_crossentropy')

# Entrenar el modelo durante el fine-tuning
checkpoint_finetune_path = "best_model_finetune.h5"
checkpoint_finetune = ModelCheckpoint(
    checkpoint_finetune_path,
    save_best_only=True,
    monitor="val_loss",
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Fine-tuning del modelo
history_finetune = model.fit(
    train_generator,
    epochs=200,
    validation_data=valid_generator,
    class_weight=class_weights,
    callbacks=[checkpoint_finetune, early_stopping],
)
# Out:
# Epoch 1/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6657
# Epoch 1: val_loss improved from inf to 0.83274, saving model to best_model_finetune.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 83s 1s/step - loss: 0.6657 - val_loss: 0.8327
# Epoch 2/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6646
# Epoch 2: val_loss did not improve from 0.83274
# 9/9 [==============================] - 8s 942ms/step - loss: 0.6646 - val_loss: 0.8501
# Epoch 3/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6541
# Epoch 3: val_loss improved from 0.83274 to 0.76217, saving model to best_model_finetune.h5
# 9/9 [==============================] - 7s 815ms/step - loss: 0.6541 - val_loss: 0.7622
# Epoch 4/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6214
# Epoch 4: val_loss did not improve from 0.76217
# 9/9 [==============================] - 8s 776ms/step - loss: 0.6214 - val_loss: 0.7952
# Epoch 5/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6069
# Epoch 5: val_loss did not improve from 0.76217
# 9/9 [==============================] - 8s 883ms/step - loss: 0.6069 - val_loss: 0.7727
# Epoch 6/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5957
# Epoch 6: val_loss did not improve from 0.76217
# 9/9 [==============================] - 6s 650ms/step - loss: 0.5957 - val_loss: 0.7836
# Epoch 7/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5908
# Epoch 7: val_loss improved from 0.76217 to 0.72551, saving model to best_model_finetune.h5
# 9/9 [==============================] - 8s 841ms/step - loss: 0.5908 - val_loss: 0.7255
# Epoch 8/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5603
# Epoch 8: val_loss did not improve from 0.72551
# 9/9 [==============================] - 7s 737ms/step - loss: 0.5603 - val_loss: 0.7572
# Epoch 9/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5830
# Epoch 9: val_loss did not improve from 0.72551
# 9/9 [==============================] - 6s 687ms/step - loss: 0.5830 - val_loss: 0.7344
# Epoch 10/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5602
# Epoch 10: val_loss did not improve from 0.72551
# 9/9 [==============================] - 6s 644ms/step - loss: 0.5602 - val_loss: 0.7557
# Epoch 11/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5409
# Epoch 11: val_loss did not improve from 0.72551
# 9/9 [==============================] - 6s 642ms/step - loss: 0.5409 - val_loss: 0.7688
# Epoch 12/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5318
# Epoch 12: val_loss improved from 0.72551 to 0.66310, saving model to best_model_finetune.h5
# 9/9 [==============================] - 9s 940ms/step - loss: 0.5318 - val_loss: 0.6631
# Epoch 13/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5375
# Epoch 13: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 918ms/step - loss: 0.5375 - val_loss: 0.7091
# Epoch 14/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5366
# Epoch 14: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 716ms/step - loss: 0.5366 - val_loss: 0.7070
# Epoch 15/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4947
# Epoch 15: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 868ms/step - loss: 0.4947 - val_loss: 0.7559
# Epoch 16/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4937
# Epoch 16: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 670ms/step - loss: 0.4937 - val_loss: 0.7624
# Epoch 17/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4894
# Epoch 17: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 878ms/step - loss: 0.4894 - val_loss: 0.7942
# Epoch 18/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4970
# Epoch 18: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 864ms/step - loss: 0.4970 - val_loss: 0.7032
# Epoch 19/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4671
# Epoch 19: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 702ms/step - loss: 0.4671 - val_loss: 0.7058
# Epoch 20/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4935
# Epoch 20: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 674ms/step - loss: 0.4935 - val_loss: 0.6775
# Epoch 21/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4619
# Epoch 21: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 801ms/step - loss: 0.4619 - val_loss: 0.7154
# Epoch 22/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4559
# Epoch 22: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 890ms/step - loss: 0.4559 - val_loss: 0.7660
# Epoch 23/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4405
# Epoch 23: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 684ms/step - loss: 0.4405 - val_loss: 0.7558
# Epoch 24/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4550
# Epoch 24: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 907ms/step - loss: 0.4550 - val_loss: 0.7658
# Epoch 25/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4381
# Epoch 25: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 713ms/step - loss: 0.4381 - val_loss: 0.8287
# Epoch 26/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4335
# Epoch 26: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 926ms/step - loss: 0.4335 - val_loss: 0.7370
# Epoch 27/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4281
# Epoch 27: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 692ms/step - loss: 0.4281 - val_loss: 0.8200
# Epoch 28/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4181
# Epoch 28: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 722ms/step - loss: 0.4181 - val_loss: 0.7678
# Epoch 29/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4054
# Epoch 29: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 861ms/step - loss: 0.4054 - val_loss: 0.7462
# Epoch 30/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4092
# Epoch 30: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 671ms/step - loss: 0.4092 - val_loss: 0.7728
# Epoch 31/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4334
# Epoch 31: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 839ms/step - loss: 0.4334 - val_loss: 0.7688
# Epoch 32/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4226
# Epoch 32: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 652ms/step - loss: 0.4226 - val_loss: 0.8073
# Epoch 33/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4049
# Epoch 33: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 860ms/step - loss: 0.4049 - val_loss: 0.8143
# Epoch 34/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3754
# Epoch 34: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 880ms/step - loss: 0.3754 - val_loss: 0.8829
# Epoch 35/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3769
# Epoch 35: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 767ms/step - loss: 0.3769 - val_loss: 0.8019
# Epoch 36/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3930
# Epoch 36: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 910ms/step - loss: 0.3930 - val_loss: 0.8970
# Epoch 37/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3723
# Epoch 37: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 710ms/step - loss: 0.3723 - val_loss: 0.8040
# Epoch 38/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3910
# Epoch 38: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 694ms/step - loss: 0.3910 - val_loss: 0.8570
# Epoch 39/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3895
# Epoch 39: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 916ms/step - loss: 0.3895 - val_loss: 0.8894
# Epoch 40/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3642
# Epoch 40: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 682ms/step - loss: 0.3642 - val_loss: 0.9087
# Epoch 41/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3885
# Epoch 41: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 950ms/step - loss: 0.3885 - val_loss: 0.8802
# Epoch 42/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3557
# Epoch 42: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 742ms/step - loss: 0.3557 - val_loss: 0.9682
# Epoch 43/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3663
# Epoch 43: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 688ms/step - loss: 0.3663 - val_loss: 0.9443
# Epoch 44/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3789
# Epoch 44: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 915ms/step - loss: 0.3789 - val_loss: 0.9197
# Epoch 45/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3612
# Epoch 45: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 710ms/step - loss: 0.3612 - val_loss: 0.9077
# Epoch 46/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3666
# Epoch 46: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 877ms/step - loss: 0.3666 - val_loss: 0.8769
# Epoch 47/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3638
# Epoch 47: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 897ms/step - loss: 0.3638 - val_loss: 0.9371
# Epoch 48/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3411
# Epoch 48: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 865ms/step - loss: 0.3411 - val_loss: 1.0082
# Epoch 49/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3304
# Epoch 49: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 751ms/step - loss: 0.3304 - val_loss: 0.9892
# Epoch 50/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3588
# Epoch 50: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 973ms/step - loss: 0.3588 - val_loss: 0.9620
# Epoch 51/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3549
# Epoch 51: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 764ms/step - loss: 0.3549 - val_loss: 1.0018
# Epoch 52/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3501
# Epoch 52: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 818ms/step - loss: 0.3501 - val_loss: 1.0228
# Epoch 53/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3625
# Epoch 53: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 914ms/step - loss: 0.3625 - val_loss: 0.9958
# Epoch 54/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3298
# Epoch 54: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 770ms/step - loss: 0.3298 - val_loss: 1.0965
# Epoch 55/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3471
# Epoch 55: val_loss did not improve from 0.66310
# 9/9 [==============================] - 6s 756ms/step - loss: 0.3471 - val_loss: 0.9482
# Epoch 56/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3405
# Epoch 56: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 793ms/step - loss: 0.3405 - val_loss: 1.0395
# Epoch 57/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3366
# Epoch 57: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 994ms/step - loss: 0.3366 - val_loss: 1.0921
# Epoch 58/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3298
# Epoch 58: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 729ms/step - loss: 0.3298 - val_loss: 1.0413
# Epoch 59/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3515
# Epoch 59: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 791ms/step - loss: 0.3515 - val_loss: 1.0581
# Epoch 60/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3386
# Epoch 60: val_loss did not improve from 0.66310
# 9/9 [==============================] - 8s 873ms/step - loss: 0.3386 - val_loss: 1.0659
# Epoch 61/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3278
# Epoch 61: val_loss did not improve from 0.66310
# 9/9 [==============================] - 7s 748ms/step - loss: 0.3278 - val_loss: 1.0884
# Epoch 62/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3288
# Epoch 62: val_loss did not improve from 0.66310
# 9/9 [==============================] - 9s 931ms/step - loss: 0.3288 - val_loss: 1.1110

# %%
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Evaluación del modelo en el conjunto de validación (test_generator) después del calentamiento
predictions_test = model.predict(test_generator)
predicted_classes_test = np.round(predictions_test).astype(int)

y_test = test_generator.classes

print("Test set classification report after fine-tuning:")
print(classification_report(y_test, predicted_classes_test, target_names=['Clase 0', 'Clase 1']))
auc_score_test = roc_auc_score(y_test, predictions_test)
print("Test set AUC Score after fine-tuning:", auc_score_test)

predictions_train = model.predict(train_b_generator, steps=len(train_b_generator), verbose=1)
predicted_classes_train = np.round(predictions_train).astype(int)


y_train = train_b_generator.classes

print("Train set classification report after fine-tuning:")
print(classification_report(y_train, predicted_classes_train, target_names=['Clase 0', 'Clase 1']))
auc_score_train = roc_auc_score(y_train, predictions_train)
print("Train set AUC Score after fine-tuning:", auc_score_train)
# Out:
# 3/3 [==============================] - 5s 234ms/step
# Test set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.86      0.45      0.59        67
#      Clase 1       0.24      0.71      0.36        17
#
#     accuracy                           0.50        84
#    macro avg       0.55      0.58      0.48        84
# weighted avg       0.73      0.50      0.54        84
#
# Test set AUC Score after fine-tuning: 0.655838454784899
# 11/11 [==============================] - 2s 172ms/step
# Train set classification report after fine-tuning:
#               precision    recall  f1-score   support
#
#      Clase 0       0.89      0.48      0.62       265
#      Clase 1       0.28      0.77      0.41        70
#
#     accuracy                           0.54       335
#    macro avg       0.58      0.63      0.52       335
# weighted avg       0.76      0.54      0.58       335
#
# Train set AUC Score after fine-tuning: 0.7019407008086254

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history, title):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Pérdida durante el entrenamiento y la validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()

    plt.suptitle(title)
    plt.show()


plot_training_curves(history_finetune, 'Curvas de Fine-Tuning')
